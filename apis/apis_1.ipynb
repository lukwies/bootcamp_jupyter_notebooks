# %% [markdown]
# ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results
# Out:
# 200
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'completed': False},
#  {'userId': 1,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'completed': True},
#  {'userId': 1,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'completed': True},
#  {'userId': 2,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'completed': False},
#  {'userId': 2,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'completed': True},
#  {'userId': 2,
#   'id': 23,
#   'title': 'et itaque necessitatibus maxime molestiae qui quas velit',
#   'completed': False},
#  {'userId': 2,
#   'id': 24,
#   'title': 'adipisci non ad dicta qui amet quaerat doloribus ea',
#   'completed': False},
#  {'userId': 2,
#   'id': 25,
#   'title': 'voluptas quo tenetur perspiciatis explicabo natus',
#   'completed': True},
#  {'userId': 2, 'id': 26, 'title': 'aliquam aut quasi', 'completed': True},
#  {'userId': 2,
#   'id': 27,
#   'title': 'veritatis pariatur delectus',
#   'completed': True},
#  {'userId': 2,
#   'id': 28,
#   'title': 'nesciunt totam sit blanditiis sit',
#   'completed': False},
#  {'userId': 2, 'id': 29, 'title': 'laborum aut in quam', 'completed': False},
#  {'userId': 2,
#   'id': 30,
#   'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis',
#   'completed': True},
#  {'userId': 2,
#   'id': 31,
#   'title': 'repudiandae totam in est sint facere fuga',
#   'completed': False},
#  {'userId': 2,
#   'id': 32,
#   'title': 'earum doloribus ea doloremque quis',
#   'completed': False},
#  {'userId': 2, 'id': 33, 'title': 'sint sit aut vero', 'completed': False},
#  {'userId': 2,
#   'id': 34,
#   'title': 'porro aut necessitatibus eaque distinctio',
#   'completed': False},
#  {'userId': 2,
#   'id': 35,
#   'title': 'repellendus veritatis molestias dicta incidunt',
#   'completed': True},
#  {'userId': 2,
#   'id': 36,
#   'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad',
#   'completed': True},
#  {'userId': 2, 'id': 37, 'title': 'sunt cum tempora', 'completed': False},
#  {'userId': 2, 'id': 38, 'title': 'totam quia non', 'completed': False},
#  {'userId': 2,
#   'id': 39,
#   'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis',
#   'completed': False},
#  {'userId': 2,
#   'id': 40,
#   'title': 'totam atque quo nesciunt',
#   'completed': True},
#  {'userId': 3,
#   'id': 41,
#   'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit',
#   'completed': False},
#  {'userId': 3,
#   'id': 42,
#   'title': 'rerum perferendis error quia ut eveniet',
#   'completed': False},
#  {'userId': 3,
#   'id': 43,
#   'title': 'tempore ut sint quis recusandae',
#   'completed': True},
#  {'userId': 3,
#   'id': 44,
#   'title': 'cum debitis quis accusamus doloremque ipsa natus sapiente omnis',
#   'completed': True},
#  {'userId': 3,
#   'id': 45,
#   'title': 'velit soluta adipisci molestias reiciendis harum',
#   'completed': False},
#  {'userId': 3,
#   'id': 46,
#   'title': 'vel voluptatem repellat nihil placeat corporis',
#   'completed': False},
#  {'userId': 3,
#   'id': 47,
#   'title': 'nam qui rerum fugiat accusamus',
#   'completed': False},
#  {'userId': 3,
#   'id': 48,
#   'title': 'sit reprehenderit omnis quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 49,
#   'title': 'ut necessitatibus aut maiores debitis officia blanditiis velit et',
#   'completed': False},
#  {'userId': 3,
#   'id': 50,
#   'title': 'cupiditate necessitatibus ullam aut quis dolor voluptate',
#   'completed': True},
#  {'userId': 3,
#   'id': 51,
#   'title': 'distinctio exercitationem ab doloribus',
#   'completed': False},
#  {'userId': 3,
#   'id': 52,
#   'title': 'nesciunt dolorum quis recusandae ad pariatur ratione',
#   'completed': False},
#  {'userId': 3,
#   'id': 53,
#   'title': 'qui labore est occaecati recusandae aliquid quam',
#   'completed': False},
#  {'userId': 3,
#   'id': 54,
#   'title': 'quis et est ut voluptate quam dolor',
#   'completed': True},
#  {'userId': 3,
#   'id': 55,
#   'title': 'voluptatum omnis minima qui occaecati provident nulla voluptatem ratione',
#   'completed': True},
#  {'userId': 3,
#   'id': 56,
#   'title': 'deleniti ea temporibus enim',
#   'completed': True},
#  {'userId': 3,
#   'id': 57,
#   'title': 'pariatur et magnam ea doloribus similique voluptatem rerum quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 58,
#   'title': 'est dicta totam qui explicabo doloribus qui dignissimos',
#   'completed': False},
#  {'userId': 3,
#   'id': 59,
#   'title': 'perspiciatis velit id laborum placeat iusto et aliquam odio',
#   'completed': False},
#  {'userId': 3,
#   'id': 60,
#   'title': 'et sequi qui architecto ut adipisci',
#   'completed': True},
#  {'userId': 4,
#   'id': 61,
#   'title': 'odit optio omnis qui sunt',
#   'completed': True},
#  {'userId': 4,
#   'id': 62,
#   'title': 'et placeat et tempore aspernatur sint numquam',
#   'completed': False},
#  {'userId': 4,
#   'id': 63,
#   'title': 'doloremque aut dolores quidem fuga qui nulla',
#   'completed': True},
#  {'userId': 4,
#   'id': 64,
#   'title': 'voluptas consequatur qui ut quia magnam nemo esse',
#   'completed': False},
#  {'userId': 4,
#   'id': 65,
#   'title': 'fugiat pariatur ratione ut asperiores necessitatibus magni',
#   'completed': False},
#  {'userId': 4,
#   'id': 66,
#   'title': 'rerum eum molestias autem voluptatum sit optio',
#   'completed': False},
#  {'userId': 4,
#   'id': 67,
#   'title': 'quia voluptatibus voluptatem quos similique maiores repellat',
#   'completed': False},
#  {'userId': 4,
#   'id': 68,
#   'title': 'aut id perspiciatis voluptatem iusto',
#   'completed': False},
#  {'userId': 4,
#   'id': 69,
#   'title': 'doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit',
#   'completed': False},
#  {'userId': 4,
#   'id': 70,
#   'title': 'ut sequi accusantium et mollitia delectus sunt',
#   'completed': False},
#  {'userId': 4, 'id': 71, 'title': 'aut velit saepe ullam', 'completed': False},
#  {'userId': 4,
#   'id': 72,
#   'title': 'praesentium facilis facere quis harum voluptatibus voluptatem eum',
#   'completed': False},
#  {'userId': 4,
#   'id': 73,
#   'title': 'sint amet quia totam corporis qui exercitationem commodi',
#   'completed': True},
#  {'userId': 4,
#   'id': 74,
#   'title': 'expedita tempore nobis eveniet laborum maiores',
#   'completed': False},
#  {'userId': 4,
#   'id': 75,
#   'title': 'occaecati adipisci est possimus totam',
#   'completed': False},
#  {'userId': 4, 'id': 76, 'title': 'sequi dolorem sed', 'completed': True},
#  {'userId': 4,
#   'id': 77,
#   'title': 'maiores aut nesciunt delectus exercitationem vel assumenda eligendi at',
#   'completed': False},
#  {'userId': 4,
#   'id': 78,
#   'title': 'reiciendis est magnam amet nemo iste recusandae impedit quaerat',
#   'completed': False},
#  {'userId': 4, 'id': 79, 'title': 'eum ipsa maxime ut', 'completed': True},
#  {'userId': 4,
#   'id': 80,
#   'title': 'tempore molestias dolores rerum sequi voluptates ipsum consequatur',
#   'completed': True},
#  {'userId': 5, 'id': 81, 'title': 'suscipit qui totam', 'completed': True},
#  {'userId': 5,
#   'id': 82,
#   'title': 'voluptates eum voluptas et dicta',
#   'completed': False},
#  {'userId': 5,
#   'id': 83,
#   'title': 'quidem at rerum quis ex aut sit quam',
#   'completed': True},
#  {'userId': 5,
#   'id': 84,
#   'title': 'sunt veritatis ut voluptate',
#   'completed': False},
#  {'userId': 5, 'id': 85, 'title': 'et quia ad iste a', 'completed': True},
#  {'userId': 5,
#   'id': 86,
#   'title': 'incidunt ut saepe autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 87,
#   'title': 'laudantium quae eligendi consequatur quia et vero autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 88,
#   'title': 'vitae aut excepturi laboriosam sint aliquam et et accusantium',
#   'completed': False},
#  {'userId': 5, 'id': 89, 'title': 'sequi ut omnis et', 'completed': True},
#  {'userId': 5,
#   'id': 90,
#   'title': 'molestiae nisi accusantium tenetur dolorem et',
#   'completed': True},
#  {'userId': 5,
#   'id': 91,
#   'title': 'nulla quis consequatur saepe qui id expedita',
#   'completed': True},
#  {'userId': 5, 'id': 92, 'title': 'in omnis laboriosam', 'completed': True},
#  {'userId': 5,
#   'id': 93,
#   'title': 'odio iure consequatur molestiae quibusdam necessitatibus quia sint',
#   'completed': True},
#  {'userId': 5,
#   'id': 94,
#   'title': 'facilis modi saepe mollitia',
#   'completed': False},
#  {'userId': 5,
#   'id': 95,
#   'title': 'vel nihil et molestiae iusto assumenda nemo quo ut',
#   'completed': True},
#  {'userId': 5,
#   'id': 96,
#   'title': 'nobis suscipit ducimus enim asperiores voluptas',
#   'completed': False},
#  {'userId': 5,
#   'id': 97,
#   'title': 'dolorum laboriosam eos qui iure aliquam',
#   'completed': False},
#  {'userId': 5,
#   'id': 98,
#   'title': 'debitis accusantium ut quo facilis nihil quis sapiente necessitatibus',
#   'completed': True},
#  {'userId': 5,
#   'id': 99,
#   'title': 'neque voluptates ratione',
#   'completed': False},
#  {'userId': 5,
#   'id': 100,
#   'title': 'excepturi a et neque qui expedita vel voluptate',
#   'completed': False},
#  {'userId': 6,
#   'id': 101,
#   'title': 'explicabo enim cumque porro aperiam occaecati minima',
#   'completed': False},
#  {'userId': 6, 'id': 102, 'title': 'sed ab consequatur', 'completed': False},
#  {'userId': 6,
#   'id': 103,
#   'title': 'non sunt delectus illo nulla tenetur enim omnis',
#   'completed': False},
#  {'userId': 6,
#   'id': 104,
#   'title': 'excepturi non laudantium quo',
#   'completed': False},
#  {'userId': 6,
#   'id': 105,
#   'title': 'totam quia dolorem et illum repellat voluptas optio',
#   'completed': True},
#  {'userId': 6,
#   'id': 106,
#   'title': 'ad illo quis voluptatem temporibus',
#   'completed': True},
#  {'userId': 6,
#   'id': 107,
#   'title': 'praesentium facilis omnis laudantium fugit ad iusto nihil nesciunt',
#   'completed': False},
#  {'userId': 6,
#   'id': 108,
#   'title': 'a eos eaque nihil et exercitationem incidunt delectus',
#   'completed': True},
#  {'userId': 6,
#   'id': 109,
#   'title': 'autem temporibus harum quisquam in culpa',
#   'completed': True},
#  {'userId': 6, 'id': 110, 'title': 'aut aut ea corporis', 'completed': True},
#  {'userId': 6,
#   'id': 111,
#   'title': 'magni accusantium labore et id quis provident',
#   'completed': False},
#  {'userId': 6,
#   'id': 112,
#   'title': 'consectetur impedit quisquam qui deserunt non rerum consequuntur eius',
#   'completed': False},
#  {'userId': 6,
#   'id': 113,
#   'title': 'quia atque aliquam sunt impedit voluptatum rerum assumenda nisi',
#   'completed': False},
#  {'userId': 6,
#   'id': 114,
#   'title': 'cupiditate quos possimus corporis quisquam exercitationem beatae',
#   'completed': False},
#  {'userId': 6, 'id': 115, 'title': 'sed et ea eum', 'completed': False},
#  {'userId': 6,
#   'id': 116,
#   'title': 'ipsa dolores vel facilis ut',
#   'completed': True},
#  {'userId': 6,
#   'id': 117,
#   'title': 'sequi quae est et qui qui eveniet asperiores',
#   'completed': False},
#  {'userId': 6,
#   'id': 118,
#   'title': 'quia modi consequatur vero fugiat',
#   'completed': False},
#  {'userId': 6,
#   'id': 119,
#   'title': 'corporis ducimus ea perspiciatis iste',
#   'completed': False},
#  {'userId': 6,
#   'id': 120,
#   'title': 'dolorem laboriosam vel voluptas et aliquam quasi',
#   'completed': False},
#  {'userId': 7,
#   'id': 121,
#   'title': 'inventore aut nihil minima laudantium hic qui omnis',
#   'completed': True},
#  {'userId': 7,
#   'id': 122,
#   'title': 'provident aut nobis culpa',
#   'completed': True},
#  {'userId': 7,
#   'id': 123,
#   'title': 'esse et quis iste est earum aut impedit',
#   'completed': False},
#  {'userId': 7, 'id': 124, 'title': 'qui consectetur id', 'completed': False},
#  {'userId': 7,
#   'id': 125,
#   'title': 'aut quasi autem iste tempore illum possimus',
#   'completed': False},
#  {'userId': 7,
#   'id': 126,
#   'title': 'ut asperiores perspiciatis veniam ipsum rerum saepe',
#   'completed': True},
#  {'userId': 7,
#   'id': 127,
#   'title': 'voluptatem libero consectetur rerum ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 128,
#   'title': 'eius omnis est qui voluptatem autem',
#   'completed': False},
#  {'userId': 7,
#   'id': 129,
#   'title': 'rerum culpa quis harum',
#   'completed': False},
#  {'userId': 7,
#   'id': 130,
#   'title': 'nulla aliquid eveniet harum laborum libero alias ut unde',
#   'completed': True},
#  {'userId': 7, 'id': 131, 'title': 'qui ea incidunt quis', 'completed': False},
#  {'userId': 7,
#   'id': 132,
#   'title': 'qui molestiae voluptatibus velit iure harum quisquam',
#   'completed': True},
#  {'userId': 7,
#   'id': 133,
#   'title': 'et labore eos enim rerum consequatur sunt',
#   'completed': True},
#  {'userId': 7,
#   'id': 134,
#   'title': 'molestiae doloribus et laborum quod ea',
#   'completed': False},
#  {'userId': 7,
#   'id': 135,
#   'title': 'facere ipsa nam eum voluptates reiciendis vero qui',
#   'completed': False},
#  {'userId': 7,
#   'id': 136,
#   'title': 'asperiores illo tempora fuga sed ut quasi adipisci',
#   'completed': False},
#  {'userId': 7, 'id': 137, 'title': 'qui sit non', 'completed': False},
#  {'userId': 7,
#   'id': 138,
#   'title': 'placeat minima consequatur rem qui ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 139,
#   'title': 'consequatur doloribus id possimus voluptas a voluptatem',
#   'completed': False},
#  {'userId': 7,
#   'id': 140,
#   'title': 'aut consectetur in blanditiis deserunt quia sed laboriosam',
#   'completed': True},
#  {'userId': 8,
#   'id': 141,
#   'title': 'explicabo consectetur debitis voluptates quas quae culpa rerum non',
#   'completed': True},
#  {'userId': 8,
#   'id': 142,
#   'title': 'maiores accusantium architecto necessitatibus reiciendis ea aut',
#   'completed': True},
#  {'userId': 8,
#   'id': 143,
#   'title': 'eum non recusandae cupiditate animi',
#   'completed': False},
#  {'userId': 8,
#   'id': 144,
#   'title': 'ut eum exercitationem sint',
#   'completed': False},
#  {'userId': 8,
#   'id': 145,
#   'title': 'beatae qui ullam incidunt voluptatem non nisi aliquam',
#   'completed': False},
#  {'userId': 8,
#   'id': 146,
#   'title': 'molestiae suscipit ratione nihil odio libero impedit vero totam',
#   'completed': True},
#  {'userId': 8,
#   'id': 147,
#   'title': 'eum itaque quod reprehenderit et facilis dolor autem ut',
#   'completed': True},
#  {'userId': 8,
#   'id': 148,
#   'title': 'esse quas et quo quasi exercitationem',
#   'completed': False},
#  {'userId': 8,
#   'id': 149,
#   'title': 'animi voluptas quod perferendis est',
#   'completed': False},
#  {'userId': 8,
#   'id': 150,
#   'title': 'eos amet tempore laudantium fugit a',
#   'completed': False},
#  {'userId': 8,
#   'id': 151,
#   'title': 'accusamus adipisci dicta qui quo ea explicabo sed vero',
#   'completed': True},
#  {'userId': 8,
#   'id': 152,
#   'title': 'odit eligendi recusandae doloremque cumque non',
#   'completed': False},
#  {'userId': 8,
#   'id': 153,
#   'title': 'ea aperiam consequatur qui repellat eos',
#   'completed': False},
#  {'userId': 8, 'id': 154, 'title': 'rerum non ex sapiente', 'completed': True},
#  {'userId': 8,
#   'id': 155,
#   'title': 'voluptatem nobis consequatur et assumenda magnam',
#   'completed': True},
#  {'userId': 8,
#   'id': 156,
#   'title': 'nam quia quia nulla repellat assumenda quibusdam sit nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 157,
#   'title': 'dolorem veniam quisquam deserunt repellendus',
#   'completed': True},
#  {'userId': 8,
#   'id': 158,
#   'title': 'debitis vitae delectus et harum accusamus aut deleniti a',
#   'completed': True},
#  {'userId': 8,
#   'id': 159,
#   'title': 'debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 160,
#   'title': 'et praesentium aliquam est',
#   'completed': False},
#  {'userId': 9,
#   'id': 161,
#   'title': 'ex hic consequuntur earum omnis alias ut occaecati culpa',
#   'completed': True},
#  {'userId': 9,
#   'id': 162,
#   'title': 'omnis laboriosam molestias animi sunt dolore',
#   'completed': True},
#  {'userId': 9,
#   'id': 163,
#   'title': 'natus corrupti maxime laudantium et voluptatem laboriosam odit',
#   'completed': False},
#  {'userId': 9,
#   'id': 164,
#   'title': 'reprehenderit quos aut aut consequatur est sed',
#   'completed': False},
#  {'userId': 9,
#   'id': 165,
#   'title': 'fugiat perferendis sed aut quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 166,
#   'title': 'quos quo possimus suscipit minima ut',
#   'completed': False},
#  {'userId': 9,
#   'id': 167,
#   'title': 'et quis minus quo a asperiores molestiae',
#   'completed': False},
#  {'userId': 9,
#   'id': 168,
#   'title': 'recusandae quia qui sunt libero',
#   'completed': False},
#  {'userId': 9,
#   'id': 169,
#   'title': 'ea odio perferendis officiis',
#   'completed': True},
#  {'userId': 9,
#   'id': 170,
#   'title': 'quisquam aliquam quia doloribus aut',
#   'completed': False},
#  {'userId': 9,
#   'id': 171,
#   'title': 'fugiat aut voluptatibus corrupti deleniti velit iste odio',
#   'completed': True},
#  {'userId': 9,
#   'id': 172,
#   'title': 'et provident amet rerum consectetur et voluptatum',
#   'completed': False},
#  {'userId': 9,
#   'id': 173,
#   'title': 'harum ad aperiam quis',
#   'completed': False},
#  {'userId': 9, 'id': 174, 'title': 'similique aut quo', 'completed': False},
#  {'userId': 9,
#   'id': 175,
#   'title': 'laudantium eius officia perferendis provident perspiciatis asperiores',
#   'completed': True},
#  {'userId': 9,
#   'id': 176,
#   'title': 'magni soluta corrupti ut maiores rem quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 177,
#   'title': 'et placeat temporibus voluptas est tempora quos quibusdam',
#   'completed': False},
#  {'userId': 9,
#   'id': 178,
#   'title': 'nesciunt itaque commodi tempore',
#   'completed': True},
#  {'userId': 9,
#   'id': 179,
#   'title': 'omnis consequuntur cupiditate impedit itaque ipsam quo',
#   'completed': True},
#  {'userId': 9,
#   'id': 180,
#   'title': 'debitis nisi et dolorem repellat et',
#   'completed': True},
#  {'userId': 10,
#   'id': 181,
#   'title': 'ut cupiditate sequi aliquam fuga maiores',
#   'completed': False},
#  {'userId': 10,
#   'id': 182,
#   'title': 'inventore saepe cumque et aut illum enim',
#   'completed': True},
#  {'userId': 10,
#   'id': 183,
#   'title': 'omnis nulla eum aliquam distinctio',
#   'completed': True},
#  {'userId': 10,
#   'id': 184,
#   'title': 'molestias modi perferendis perspiciatis',
#   'completed': False},
#  {'userId': 10,
#   'id': 185,
#   'title': 'voluptates dignissimos sed doloribus animi quaerat aut',
#   'completed': False},
#  {'userId': 10,
#   'id': 186,
#   'title': 'explicabo odio est et',
#   'completed': False},
#  {'userId': 10,
#   'id': 187,
#   'title': 'consequuntur animi possimus',
#   'completed': False},
#  {'userId': 10, 'id': 188, 'title': 'vel non beatae est', 'completed': True},
#  {'userId': 10,
#   'id': 189,
#   'title': 'culpa eius et voluptatem et',
#   'completed': True},
#  {'userId': 10,
#   'id': 190,
#   'title': 'accusamus sint iusto et voluptatem exercitationem',
#   'completed': True},
#  {'userId': 10,
#   'id': 191,
#   'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 192,
#   'title': 'ut quas possimus exercitationem sint voluptates',
#   'completed': False},
#  {'userId': 10,
#   'id': 193,
#   'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a',
#   'completed': True},
#  {'userId': 10,
#   'id': 194,
#   'title': 'sed ut vero sit molestiae',
#   'completed': False},
#  {'userId': 10,
#   'id': 195,
#   'title': 'rerum ex veniam mollitia voluptatibus pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 196,
#   'title': 'consequuntur aut ut fugit similique',
#   'completed': True},
#  {'userId': 10,
#   'id': 197,
#   'title': 'dignissimos quo nobis earum saepe',
#   'completed': True},
#  {'userId': 10,
#   'id': 198,
#   'title': 'quis eius est sint explicabo',
#   'completed': True},
#  {'userId': 10,
#   'id': 199,
#   'title': 'numquam repellendus a magnam',
#   'completed': True},
#  {'userId': 10,
#   'id': 200,
#   'title': 'ipsam aperiam voluptates qui',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '25093616147',
#   'type': 'PushEvent',
#   'actor': {'id': 65786577,
#    'login': 'Andrii-Vekker',
#    'display_login': 'Andrii-Vekker',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Andrii-Vekker',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65786577?'},
#   'repo': {'id': 561687626,
#    'name': 'Andrii-Vekker/goit-react-hw-08-phonebook',
#    'url': 'https://api.github.com/repos/Andrii-Vekker/goit-react-hw-08-phonebook'},
#   'payload': {'push_id': 11588386476,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '40d2c2a79b3cc20691e58f0d9cf5df6fabcdd143',
#    'before': '577ec3c2bf6119ff992ac7458db22c9d7a788c13',
#    'commits': [{'sha': '40d2c2a79b3cc20691e58f0d9cf5df6fabcdd143',
#      'author': {'email': '65786577+Andrii-Vekker@users.noreply.github.com',
#       'name': 'Andrii-Vekker'},
#      'message': 'Updates',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Andrii-Vekker/goit-react-hw-08-phonebook/commits/40d2c2a79b3cc20691e58f0d9cf5df6fabcdd143'}]},
#   'public': True,
#   'created_at': '2022-11-08T08:35:23Z'},
#  {'id': '25093616528',
#   'type': 'IssuesEvent',
#   'actor': {'id': 914682,
#    'login': 'wilkinsona',
#    'display_login': 'wilkinsona',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wilkinsona',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/914682?'},
#   'repo': {'id': 6296790,
#    'name': 'spring-projects/spring-boot',
#    'url': 'https://api.github.com/repos/spring-projects/spring-boot'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/spring-projects/spring-boot/issues/33063',
#     'repository_url': 'https://api.github.com/repos/spring-projects/spring-boot',
#     'labels_url': 'https://api.github.com/repos/spring-projects/spring-boot/issues/33063/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/spring-projects/spring-boot/issues/33063/comments',
#     'events_url': 'https://api.github.com/repos/spring-projects/spring-boot/issues/33063/events',
#     'html_url': 'https://github.com/spring-projects/spring-boot/issues/33063',
#     'id': 1439731495,
#     'node_id': 'I_kwDOAGAU1s5V0I8n',
#     'number': 33063,
#     'title': 'Upgrade to Spring Security 6.0.0-RC2',
#     'user': {'login': 'wilkinsona',
#      'id': 914682,
#      'node_id': 'MDQ6VXNlcjkxNDY4Mg==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/914682?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/wilkinsona',
#      'html_url': 'https://github.com/wilkinsona',
#      'followers_url': 'https://api.github.com/users/wilkinsona/followers',
#      'following_url': 'https://api.github.com/users/wilkinsona/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/wilkinsona/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/wilkinsona/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/wilkinsona/subscriptions',
#      'organizations_url': 'https://api.github.com/users/wilkinsona/orgs',
#      'repos_url': 'https://api.github.com/users/wilkinsona/repos',
#      'events_url': 'https://api.github.com/users/wilkinsona/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/wilkinsona/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 568657130,
#       'node_id': 'MDU6TGFiZWw1Njg2NTcxMzA=',
#       'url': 'https://api.github.com/repos/spring-projects/spring-boot/labels/type:%20dependency-upgrade',
#       'name': 'type: dependency-upgrade',
#       'color': 'e3d9fc',
#       'default': False,
#       'description': 'A dependency upgrade'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': {'url': 'https://api.github.com/repos/spring-projects/spring-boot/milestones/276',
#      'html_url': 'https://github.com/spring-projects/spring-boot/milestone/276',
#      'labels_url': 'https://api.github.com/repos/spring-projects/spring-boot/milestones/276/labels',
#      'id': 8566495,
#      'node_id': 'MI_kwDOAGAU1s4Agrbf',
#      'number': 276,
#      'title': '3.0.0-RC2',
#      'description': '',
#      'creator': {'login': 'wilkinsona',
#       'id': 914682,
#       'node_id': 'MDQ6VXNlcjkxNDY4Mg==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/914682?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/wilkinsona',
#       'html_url': 'https://github.com/wilkinsona',
#       'followers_url': 'https://api.github.com/users/wilkinsona/followers',
#       'following_url': 'https://api.github.com/users/wilkinsona/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/wilkinsona/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/wilkinsona/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/wilkinsona/subscriptions',
#       'organizations_url': 'https://api.github.com/users/wilkinsona/orgs',
#       'repos_url': 'https://api.github.com/users/wilkinsona/repos',
#       'events_url': 'https://api.github.com/users/wilkinsona/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/wilkinsona/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 28,
#      'closed_issues': 92,
#      'state': 'open',
#      'created_at': '2022-10-21T10:24:49Z',
#      'updated_at': '2022-11-08T08:35:24Z',
#      'due_on': '2022-11-10T08:00:00Z',
#      'closed_at': None},
#     'comments': 0,
#     'created_at': '2022-11-08T08:35:24Z',
#     'updated_at': '2022-11-08T08:35:24Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
#     'active_lock_reason': None,
#     'body': None,
#     'reactions': {'url': 'https://api.github.com/repos/spring-projects/spring-boot/issues/33063/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/spring-projects/spring-boot/issues/33063/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None}},
#   'public': True,
#   'created_at': '2022-11-08T08:35:24Z',
#   'org': {'id': 317776,
#    'login': 'spring-projects',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/spring-projects',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/317776?'}},
#  {'id': '25093616527',
#   'type': 'CreateEvent',
#   'actor': {'id': 117719195,
#    'login': 'randomvpslol',
#    'display_login': 'randomvpslol',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/randomvpslol',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/117719195?'},
#   'repo': {'id': 563257903,
#    'name': 'randomvpslol/rdplol',
#    'url': 'https://api.github.com/repos/randomvpslol/rdplol'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-08T08:35:24Z'},
#  {'id': '25093616529',
#   'type': 'CreateEvent',
#   'actor': {'id': 100126640,
#    'login': 'does-not-compile',
#    'display_login': 'does-not-compile',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/does-not-compile',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/100126640?'},
#   'repo': {'id': 561243646,
#    'name': 'does-not-compile/Seattle_Housing_EDA',
#    'url': 'https://api.github.com/repos/does-not-compile/Seattle_Housing_EDA'},
#   'payload': {'ref': 'updates',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'EDA on the Kings County housing market.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-08T08:35:24Z'},
#  {'id': '25093616500',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 43041,
#    'login': 'danielfone',
#    'display_login': 'danielfone',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/danielfone',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43041?'},
#   'repo': {'id': 7600761,
#    'name': 'danielfone/as_csv',
#    'url': 'https://api.github.com/repos/danielfone/as_csv'},
#   'payload': {'action': 'closed',
#    'number': 10,
#    'pull_request': {'url': 'https://api.github.com/repos/danielfone/as_csv/pulls/10',
#     'id': 1113515558,
#     'node_id': 'PR_kwDOAHP6ec5CXuYm',
#     'html_url': 'https://github.com/danielfone/as_csv/pull/10',
#     'diff_url': 'https://github.com/danielfone/as_csv/pull/10.diff',
#     'patch_url': 'https://github.com/danielfone/as_csv/pull/10.patch',
#     'issue_url': 'https://api.github.com/repos/danielfone/as_csv/issues/10',
#     'number': 10,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Support Ruby 3 and Rails 7',
#     'user': {'login': 'danielfone',
#      'id': 43041,
#      'node_id': 'MDQ6VXNlcjQzMDQx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/43041?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/danielfone',
#      'html_url': 'https://github.com/danielfone',
#      'followers_url': 'https://api.github.com/users/danielfone/followers',
#      'following_url': 'https://api.github.com/users/danielfone/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/danielfone/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/danielfone/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/danielfone/subscriptions',
#      'organizations_url': 'https://api.github.com/users/danielfone/orgs',
#      'repos_url': 'https://api.github.com/users/danielfone/repos',
#      'events_url': 'https://api.github.com/users/danielfone/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/danielfone/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2022-11-08T00:22:37Z',
#     'updated_at': '2022-11-08T08:35:24Z',
#     'closed_at': '2022-11-08T08:35:23Z',
#     'merged_at': '2022-11-08T08:35:23Z',
#     'merge_commit_sha': '7b7bcb8d7d305c17d0216f1939512fe640a36884',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/danielfone/as_csv/pulls/10/commits',
#     'review_comments_url': 'https://api.github.com/repos/danielfone/as_csv/pulls/10/comments',
#     'review_comment_url': 'https://api.github.com/repos/danielfone/as_csv/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/danielfone/as_csv/issues/10/comments',
#     'statuses_url': 'https://api.github.com/repos/danielfone/as_csv/statuses/6803ed5473ba5c80e34ec7d08f1e83df9d4caaa7',
#     'head': {'label': 'danielfone:v3',
#      'ref': 'v3',
#      'sha': '6803ed5473ba5c80e34ec7d08f1e83df9d4caaa7',
#      'user': {'login': 'danielfone',
#       'id': 43041,
#       'node_id': 'MDQ6VXNlcjQzMDQx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/43041?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/danielfone',
#       'html_url': 'https://github.com/danielfone',
#       'followers_url': 'https://api.github.com/users/danielfone/followers',
#       'following_url': 'https://api.github.com/users/danielfone/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/danielfone/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/danielfone/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/danielfone/subscriptions',
#       'organizations_url': 'https://api.github.com/users/danielfone/orgs',
#       'repos_url': 'https://api.github.com/users/danielfone/repos',
#       'events_url': 'https://api.github.com/users/danielfone/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/danielfone/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 7600761,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk3NjAwNzYx',
#       'name': 'as_csv',
#       'full_name': 'danielfone/as_csv',
#       'private': False,
#       'owner': {'login': 'danielfone',
#        'id': 43041,
#        'node_id': 'MDQ6VXNlcjQzMDQx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/43041?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/danielfone',
#        'html_url': 'https://github.com/danielfone',
#        'followers_url': 'https://api.github.com/users/danielfone/followers',
#        'following_url': 'https://api.github.com/users/danielfone/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/danielfone/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/danielfone/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/danielfone/subscriptions',
#        'organizations_url': 'https://api.github.com/users/danielfone/orgs',
#        'repos_url': 'https://api.github.com/users/danielfone/repos',
#        'events_url': 'https://api.github.com/users/danielfone/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/danielfone/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/danielfone/as_csv',
#       'description': 'Instant CSV support for Rails',
#       'fork': False,
#       'url': 'https://api.github.com/repos/danielfone/as_csv',
#       'forks_url': 'https://api.github.com/repos/danielfone/as_csv/forks',
#       'keys_url': 'https://api.github.com/repos/danielfone/as_csv/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/danielfone/as_csv/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/danielfone/as_csv/teams',
#       'hooks_url': 'https://api.github.com/repos/danielfone/as_csv/hooks',
#       'issue_events_url': 'https://api.github.com/repos/danielfone/as_csv/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/danielfone/as_csv/events',
#       'assignees_url': 'https://api.github.com/repos/danielfone/as_csv/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/danielfone/as_csv/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/danielfone/as_csv/tags',
#       'blobs_url': 'https://api.github.com/repos/danielfone/as_csv/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/danielfone/as_csv/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/danielfone/as_csv/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/danielfone/as_csv/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/danielfone/as_csv/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/danielfone/as_csv/languages',
#       'stargazers_url': 'https://api.github.com/repos/danielfone/as_csv/stargazers',
#       'contributors_url': 'https://api.github.com/repos/danielfone/as_csv/contributors',
#       'subscribers_url': 'https://api.github.com/repos/danielfone/as_csv/subscribers',
#       'subscription_url': 'https://api.github.com/repos/danielfone/as_csv/subscription',
#       'commits_url': 'https://api.github.com/repos/danielfone/as_csv/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/danielfone/as_csv/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/danielfone/as_csv/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/danielfone/as_csv/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/danielfone/as_csv/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/danielfone/as_csv/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/danielfone/as_csv/merges',
#       'archive_url': 'https://api.github.com/repos/danielfone/as_csv/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/danielfone/as_csv/downloads',
#       'issues_url': 'https://api.github.com/repos/danielfone/as_csv/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/danielfone/as_csv/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/danielfone/as_csv/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/danielfone/as_csv/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/danielfone/as_csv/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/danielfone/as_csv/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/danielfone/as_csv/deployments',
#       'created_at': '2013-01-14T08:24:54Z',
#       'updated_at': '2021-08-05T20:41:16Z',
#       'pushed_at': '2022-11-08T08:35:23Z',
#       'git_url': 'git://github.com/danielfone/as_csv.git',
#       'ssh_url': 'git@github.com:danielfone/as_csv.git',
#       'clone_url': 'https://github.com/danielfone/as_csv.git',
#       'svn_url': 'https://github.com/danielfone/as_csv',
#       'homepage': None,
#       'size': 86,
#       'stargazers_count': 19,
#       'watchers_count': 19,
#       'language': 'Ruby',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 6,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 6,
#       'open_issues': 3,
#       'watchers': 19,
#       'default_branch': 'master'}},
#     'base': {'label': 'danielfone:master',
#      'ref': 'master',
#      'sha': '2ed2a6c41b2671cf3e7e8d32882bba888f6300c0',
#      'user': {'login': 'danielfone',
#       'id': 43041,
#       'node_id': 'MDQ6VXNlcjQzMDQx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/43041?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/danielfone',
#       'html_url': 'https://github.com/danielfone',
#       'followers_url': 'https://api.github.com/users/danielfone/followers',
#       'following_url': 'https://api.github.com/users/danielfone/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/danielfone/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/danielfone/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/danielfone/subscriptions',
#       'organizations_url': 'https://api.github.com/users/danielfone/orgs',
#       'repos_url': 'https://api.github.com/users/danielfone/repos',
#       'events_url': 'https://api.github.com/users/danielfone/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/danielfone/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 7600761,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk3NjAwNzYx',
#       'name': 'as_csv',
#       'full_name': 'danielfone/as_csv',
#       'private': False,
#       'owner': {'login': 'danielfone',
#        'id': 43041,
#        'node_id': 'MDQ6VXNlcjQzMDQx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/43041?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/danielfone',
#        'html_url': 'https://github.com/danielfone',
#        'followers_url': 'https://api.github.com/users/danielfone/followers',
#        'following_url': 'https://api.github.com/users/danielfone/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/danielfone/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/danielfone/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/danielfone/subscriptions',
#        'organizations_url': 'https://api.github.com/users/danielfone/orgs',
#        'repos_url': 'https://api.github.com/users/danielfone/repos',
#        'events_url': 'https://api.github.com/users/danielfone/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/danielfone/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/danielfone/as_csv',
#       'description': 'Instant CSV support for Rails',
#       'fork': False,
#       'url': 'https://api.github.com/repos/danielfone/as_csv',
#       'forks_url': 'https://api.github.com/repos/danielfone/as_csv/forks',
#       'keys_url': 'https://api.github.com/repos/danielfone/as_csv/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/danielfone/as_csv/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/danielfone/as_csv/teams',
#       'hooks_url': 'https://api.github.com/repos/danielfone/as_csv/hooks',
#       'issue_events_url': 'https://api.github.com/repos/danielfone/as_csv/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/danielfone/as_csv/events',
#       'assignees_url': 'https://api.github.com/repos/danielfone/as_csv/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/danielfone/as_csv/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/danielfone/as_csv/tags',
#       'blobs_url': 'https://api.github.com/repos/danielfone/as_csv/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/danielfone/as_csv/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/danielfone/as_csv/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/danielfone/as_csv/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/danielfone/as_csv/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/danielfone/as_csv/languages',
#       'stargazers_url': 'https://api.github.com/repos/danielfone/as_csv/stargazers',
#       'contributors_url': 'https://api.github.com/repos/danielfone/as_csv/contributors',
#       'subscribers_url': 'https://api.github.com/repos/danielfone/as_csv/subscribers',
#       'subscription_url': 'https://api.github.com/repos/danielfone/as_csv/subscription',
#       'commits_url': 'https://api.github.com/repos/danielfone/as_csv/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/danielfone/as_csv/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/danielfone/as_csv/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/danielfone/as_csv/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/danielfone/as_csv/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/danielfone/as_csv/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/danielfone/as_csv/merges',
#       'archive_url': 'https://api.github.com/repos/danielfone/as_csv/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/danielfone/as_csv/downloads',
#       'issues_url': 'https://api.github.com/repos/danielfone/as_csv/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/danielfone/as_csv/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/danielfone/as_csv/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/danielfone/as_csv/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/danielfone/as_csv/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/danielfone/as_csv/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/danielfone/as_csv/deployments',
#       'created_at': '2013-01-14T08:24:54Z',
#       'updated_at': '2021-08-05T20:41:16Z',
#       'pushed_at': '2022-11-08T08:35:23Z',
#       'git_url': 'git://github.com/danielfone/as_csv.git',
#       'ssh_url': 'git@github.com:danielfone/as_csv.git',
#       'clone_url': 'https://github.com/danielfone/as_csv.git',
#       'svn_url': 'https://github.com/danielfone/as_csv',
#       'homepage': None,
#       'size': 86,
#       'stargazers_count': 19,
#       'watchers_count': 19,
#       'language': 'Ruby',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 6,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 6,
#       'open_issues': 3,
#       'watchers': 19,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/danielfone/as_csv/pulls/10'},
#      'html': {'href': 'https://github.com/danielfone/as_csv/pull/10'},
#      'issue': {'href': 'https://api.github.com/repos/danielfone/as_csv/issues/10'},
#      'comments': {'href': 'https://api.github.com/repos/danielfone/as_csv/issues/10/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/danielfone/as_csv/pulls/10/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/danielfone/as_csv/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/danielfone/as_csv/pulls/10/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/danielfone/as_csv/statuses/6803ed5473ba5c80e34ec7d08f1e83df9d4caaa7'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'danielfone',
#      'id': 43041,
#      'node_id': 'MDQ6VXNlcjQzMDQx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/43041?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/danielfone',
#      'html_url': 'https://github.com/danielfone',
#      'followers_url': 'https://api.github.com/users/danielfone/followers',
#      'following_url': 'https://api.github.com/users/danielfone/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/danielfone/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/danielfone/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/danielfone/subscriptions',
#      'organizations_url': 'https://api.github.com/users/danielfone/orgs',
#      'repos_url': 'https://api.github.com/users/danielfone/repos',
#      'events_url': 'https://api.github.com/users/danielfone/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/danielfone/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 9,
#     'additions': 190,
#     'deletions': 980,
#     'changed_files': 51}},
#   'public': True,
#   'created_at': '2022-11-08T08:35:24Z'},
#  {'id': '25093616091',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 302950058,
#    'name': 'gazab/vatterhem_history',
#    'url': 'https://api.github.com/repos/gazab/vatterhem_history'},
#   'payload': {'push_id': 11588386444,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '952a05ceaed5c38d705ac02710699d90418da008',
#    'before': 'e6ebbd402f101ded1c5aa38f51448ed42503cd4b',
#    'commits': [{'sha': '952a05ceaed5c38d705ac02710699d90418da008',
#      'author': {'email': 'actions@users.noreply.github.com',
#       'name': 'Automated'},
#      'message': 'Latest data: Tue Nov  8 08:35:21 UTC 2022',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/gazab/vatterhem_history/commits/952a05ceaed5c38d705ac02710699d90418da008'}]},
#   'public': True,
#   'created_at': '2022-11-08T08:35:23Z'},
#  {'id': '25093616142',
#   'type': 'PushEvent',
#   'actor': {'id': 37274612,
#    'login': 'jorgegoco',
#    'display_login': 'jorgegoco',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorgegoco',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37274612?'},
#   'repo': {'id': 560530365,
#    'name': 'jorgegoco/To-Do-List',
#    'url': 'https://api.github.com/repos/jorgegoco/To-Do-List'},
#   'payload': {'push_id': 11588386520,
#    'size': 5,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5226c72aa9e50884f4d04cb262a31ec81e51b2cb',
#    'before': '8f0a1054146fbd786f0728b03a0a87a4cc3a74b2',
#    'commits': [{'sha': '851f6c42189799e7bdf5d19a0e9271d7d31fef4f',
#      'author': {'email': 'jorgegoco70@gmail.com', 'name': 'jorgegoco'},
#      'message': 'Add the checkbox funcionality',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/jorgegoco/To-Do-List/commits/851f6c42189799e7bdf5d19a0e9271d7d31fef4f'},
#     {'sha': '0c7b451e0cbd6ddabf099b727d1069bee53a8ad0',
#      'author': {'email': 'jorgegoco70@gmail.com', 'name': 'jorgegoco'},
#      'message': 'Fix linter errors',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/jorgegoco/To-Do-List/commits/0c7b451e0cbd6ddabf099b727d1069bee53a8ad0'},
#     {'sha': '1c08dad783327838229c7d12a6e3969cbbf07e02',
#      'author': {'email': 'jorgegoco70@gmail.com', 'name': 'jorgegoco'},
#      'message': 'Fix minor things',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/jorgegoco/To-Do-List/commits/1c08dad783327838229c7d12a6e3969cbbf07e02'},
#     {'sha': '6de35a1b92002dbf1c0c5eca5ca1168c9c133796',
#      'author': {'email': 'jorgegoco70@gmail.com', 'name': 'jorgegoco'},
#      'message': 'Remove unused code',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/jorgegoco/To-Do-List/commits/6de35a1b92002dbf1c0c5eca5ca1168c9c133796'},
#     {'sha': '5226c72aa9e50884f4d04cb262a31ec81e51b2cb',
#      'author': {'email': 'jorgegoco70@gmail.com', 'name': 'jorgegoco'},
#      'message': 'Merge pull request #3 from jorgegoco/checkbox\n\nTo Do list: interactive list',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jorgegoco/To-Do-List/commits/5226c72aa9e50884f4d04cb262a31ec81e51b2cb'}]},
#   'public': True,
#   'created_at': '2022-11-08T08:35:23Z'},
#  {'id': '25093616530',
#   'type': 'CreateEvent',
#   'actor': {'id': 67735097,
#    'login': 'myname855',
#    'display_login': 'myname855',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/myname855',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67735097?'},
#   'repo': {'id': 563257907,
#    'name': 'myname855/myname855',
#    'url': 'https://api.github.com/repos/myname855/myname855'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'Config files for my GitHub profile.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-08T08:35:24Z'},
#  {'id': '25093616487',
#   'type': 'PublicEvent',
#   'actor': {'id': 84401705,
#    'login': 'AntmJS',
#    'display_login': 'AntmJS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AntmJS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84401705?'},
#   'repo': {'id': 563232154,
#    'name': 'AntmJS/antd-pro',
#    'url': 'https://api.github.com/repos/AntmJS/antd-pro'},
#   'payload': {},
#   'public': True,
#   'created_at': '2022-11-08T08:35:24Z',
#   'org': {'id': 84401705,
#    'login': 'AntmJS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/AntmJS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84401705?'}},
#  {'id': '25093616478',
#   'type': 'PushEvent',
#   'actor': {'id': 112465772,
#    'login': 'JosvaMandixCarlsen',
#    'display_login': 'JosvaMandixCarlsen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JosvaMandixCarlsen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/112465772?'},
#   'repo': {'id': 560312053,
#    'name': 'JEJ-2022/Spil-Spil',
#    'url': 'https://api.github.com/repos/JEJ-2022/Spil-Spil'},
#   'payload': {'push_id': 11588386652,
#    'size': 3,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '37b813fb0dc3091dae39c2c534962a60946e04d4',
#    'before': 'b92e88983993bfb0f5cb61bb1863f160125347aa',
#    'commits': [{'sha': '6fb7232fc06f0698b96dcc0040c969ae99e42ee3',
#      'author': {'email': 'spiljosicom@gmail.com',
#       'name': 'Josva Mandix Carlsen'},
#      'message': 'tank',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/JEJ-2022/Spil-Spil/commits/6fb7232fc06f0698b96dcc0040c969ae99e42ee3'},
#     {'sha': '6a88a280297f6a5ec3fd7718679470f9773638af',
#      'author': {'email': '112465772+JosvaMandixCarlsen@users.noreply.github.com',
#       'name': 'JosvaMandixCarlsen'},
#      'message': 'Merge pull request #3 from JosvaMandixCarlsen/Josva\n\ntank',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/JEJ-2022/Spil-Spil/commits/6a88a280297f6a5ec3fd7718679470f9773638af'},
#     {'sha': '37b813fb0dc3091dae39c2c534962a60946e04d4',
#      'author': {'email': '112465772+JosvaMandixCarlsen@users.noreply.github.com',
#       'name': 'JosvaMandixCarlsen'},
#      'message': 'Merge pull request #4 from JEJ-2022/Josva\n\nJosva',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JEJ-2022/Spil-Spil/commits/37b813fb0dc3091dae39c2c534962a60946e04d4'}]},
#   'public': True,
#   'created_at': '2022-11-08T08:35:24Z',
#   'org': {'id': 117153375,
#    'login': 'JEJ-2022',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/JEJ-2022',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/117153375?'}},
#  {'id': '25093616131',
#   'type': 'CreateEvent',
#   'actor': {'id': 101805862,
#    'login': 'Jkm3105',
#    'display_login': 'Jkm3105',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jkm3105',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101805862?'},
#   'repo': {'id': 563257896,
#    'name': 'Jkm3105/Food-Ordering-website-frontend',
#    'url': 'https://api.github.com/repos/Jkm3105/Food-Ordering-website-frontend'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'With Love for Foodies , Home delivery store provides an seemless experience to the foodies to order their favourite food  With Team work and Collabrating with friends created this food ordering website where the front end work is done withDev Modi gitprofile: www.github.com/777Devmodi and the backend has been handled by Harshvi Shah done in PHP.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-08T08:35:23Z'},
#  {'id': '25093615093',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 238993633,
#    'name': 'instacart/radium',
#    'url': 'https://api.github.com/repos/instacart/radium'},
#   'payload': {'action': 'closed',
#    'number': 464,
#    'pull_request': {'url': 'https://api.github.com/repos/instacart/radium/pulls/464',
#     'id': 1094972541,
#     'node_id': 'PR_kwDODj7A4c5BQ_R9',
#     'html_url': 'https://github.com/instacart/radium/pull/464',
#     'diff_url': 'https://github.com/instacart/radium/pull/464.diff',
#     'patch_url': 'https://github.com/instacart/radium/pull/464.patch',
#     'issue_url': 'https://api.github.com/repos/instacart/radium/issues/464',
#     'number': 464,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump @babel/core from 7.12.10 to 7.19.6',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [@babel/core](https://github.com/babel/babel/tree/HEAD/packages/babel-core) from 7.12.10 to 7.19.6.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/babel/babel/releases"><code>@\u200bbabel/core</code>\'s releases</a>.</em></p>\n<blockquote>\n<h2>v7.19.6 (2022-10-20)</h2>\n<p>Thanks <a href="https://github.com/lomirus"><code>@\u200blomirus</code></a> for your first PR!</p>\n<h4>:eyeglasses: Spec Compliance</h4>\n<ul>\n<li><code>babel-plugin-proposal-decorators</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/15059">#15059</a> Ensure non-static decorators are applied when a class is instantiated. (<a href="https://github.com/JLHwung"><code>@\u200bJLHwung</code></a>)</li>\n</ul>\n</li>\n</ul>\n<h4>:bug: Bug Fix</h4>\n<ul>\n<li><code>babel-parser</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/15062">#15062</a> Fix parsing of block comments nested in flow comments (<a href="https://github.com/nicolo-ribaudo"><code>@\u200bnicolo-ribaudo</code></a>)</li>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/15052">#15052</a> fix: improve module block program location tracking (<a href="https://github.com/JLHwung"><code>@\u200bJLHwung</code></a>)</li>\n</ul>\n</li>\n<li><code>babel-plugin-transform-runtime</code>, <code>babel-runtime-corejs2</code>, <code>babel-runtime-corejs3</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/15060">#15060</a> Ensure <code>@babel/runtime-corejs3/core-js/*.js</code> can be imported on Node.js 17+ (<a href="https://github.com/JLHwung"><code>@\u200bJLHwung</code></a>)</li>\n</ul>\n</li>\n<li><code>babel-preset-env</code>, <code>babel-traverse</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/15043">#15043</a> fix: preserve this for <code>super.*</code> template tags (<a href="https://github.com/liuxingbaoyu"><code>@\u200bliuxingbaoyu</code></a>)</li>\n</ul>\n</li>\n</ul>\n<h4>:nail_care: Polish</h4>\n<ul>\n<li><code>babel-generator</code>, <code>babel-plugin-transform-flow-comments</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/15037">#15037</a> Improve generation of comments without location (<a href="https://github.com/liuxingbaoyu"><code>@\u200bliuxingbaoyu</code></a>)</li>\n</ul>\n</li>\n</ul>\n<h4>:memo: Documentation</h4>\n<ul>\n<li><code>babel-standalone</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/15055">#15055</a> Fix missing <code>transformSync</code> function name (<a href="https://github.com/lomirus"><code>@\u200blomirus</code></a>)</li>\n</ul>\n</li>\n</ul>\n<h4>:house: Internal</h4>\n<ul>\n<li><code>babel-parser</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/15056">#15056</a> Use <code>startLoc.index</code> instead of carrying around <code>start</code> (<a href="https://github.com/nicolo-ribaudo"><code>@\u200bnicolo-ribaudo</code></a>)</li>\n</ul>\n</li>\n<li>Other\n<ul>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/15035">#15035</a> chore: Update yarn 3.2.4 (<a href="https://github.com/liuxingbaoyu"><code>@\u200bliuxingbaoyu</code></a>)</li>\n</ul>\n</li>\n</ul>\n<h4>:running_woman: Performance</h4>\n<ul>\n<li><code>babel-core</code>, <code>babel-standalone</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/15023">#15023</a> Don\'t bundle unnecessary plugins in <code>@babel/standalone</code> (<a href="https://github.com/nicolo-ribaudo"><code>@\u200bnicolo-ribaudo</code></a>)</li>\n</ul>\n</li>\n</ul>\n<h4>Committers: 4</h4>\n<ul>\n<li>Huáng Jùnliàng (<a href="https://github.com/JLHwung"><code>@\u200bJLHwung</code></a>)</li>\n<li>Lomírus (<a href="https://github.com/lomirus"><code>@\u200blomirus</code></a>)</li>\n<li>Nicolò Ribaudo (<a href="https://github.com/nicolo-ribaudo"><code>@\u200bnicolo-ribaudo</code></a>) ...
#     'created_at': '2022-10-21T08:06:15Z',
#     'updated_at': '2022-11-08T08:35:19Z',
#     'closed_at': '2022-11-08T08:35:19Z',
#     'merged_at': None,
#     'merge_commit_sha': '73d57af7bb342e327c5f5f2c78684cd62aa23d92',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 2352159242,
#       'node_id': 'MDU6TGFiZWwyMzUyMTU5MjQy',
#       'url': 'https://api.github.com/repos/instacart/radium/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'},
#      {'id': 2352177466,
#       'node_id': 'MDU6TGFiZWwyMzUyMTc3NDY2',
#       'url': 'https://api.github.com/repos/instacart/radium/labels/javascript',
#       'name': 'javascript',
#       'color': '168700',
#       'default': False,
#       'description': 'Pull requests that update Javascript code'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/instacart/radium/pulls/464/commits',
#     'review_comments_url': 'https://api.github.com/repos/instacart/radium/pulls/464/comments',
#     'review_comment_url': 'https://api.github.com/repos/instacart/radium/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/instacart/radium/issues/464/comments',
#     'statuses_url': 'https://api.github.com/repos/instacart/radium/statuses/2f24b9effdc32dfa9652ad619f4570b650eabe02',
#     'head': {'label': 'instacart:dependabot/npm_and_yarn/babel/core-7.19.6',
#      'ref': 'dependabot/npm_and_yarn/babel/core-7.19.6',
#      'sha': '2f24b9effdc32dfa9652ad619f4570b650eabe02',
#      'user': {'login': 'instacart',
#       'id': 3732412,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM3MzI0MTI=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/3732412?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/instacart',
#       'html_url': 'https://github.com/instacart',
#       'followers_url': 'https://api.github.com/users/instacart/followers',
#       'following_url': 'https://api.github.com/users/instacart/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/instacart/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/instacart/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/instacart/subscriptions',
#       'organizations_url': 'https://api.github.com/users/instacart/orgs',
#       'repos_url': 'https://api.github.com/users/instacart/repos',
#       'events_url': 'https://api.github.com/users/instacart/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/instacart/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 238993633,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMzg5OTM2MzM=',
#       'name': 'radium',
#       'full_name': 'instacart/radium',
#       'private': False,
#       'owner': {'login': 'instacart',
#        'id': 3732412,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM3MzI0MTI=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/3732412?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/instacart',
#        'html_url': 'https://github.com/instacart',
#        'followers_url': 'https://api.github.com/users/instacart/followers',
#        'following_url': 'https://api.github.com/users/instacart/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/instacart/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/instacart/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/instacart/subscriptions',
#        'organizations_url': 'https://api.github.com/users/instacart/orgs',
#        'repos_url': 'https://api.github.com/users/instacart/repos',
#        'events_url': 'https://api.github.com/users/instacart/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/instacart/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/instacart/radium',
#       'description': 'A toolchain for React component styling.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/instacart/radium',
#       'forks_url': 'https://api.github.com/repos/instacart/radium/forks',
#       'keys_url': 'https://api.github.com/repos/instacart/radium/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/instacart/radium/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/instacart/radium/teams',
#       'hooks_url': 'https://api.github.com/repos/instacart/radium/hooks',
#       'issue_events_url': 'https://api.github.com/repos/instacart/radium/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/instacart/radium/events',
#       'assignees_url': 'https://api.github.com/repos/instacart/radium/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/instacart/radium/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/instacart/radium/tags',
#       'blobs_url': 'https://api.github.com/repos/instacart/radium/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/instacart/radium/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/instacart/radium/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/instacart/radium/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/instacart/radium/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/instacart/radium/languages',
#       'stargazers_url': 'https://api.github.com/repos/instacart/radium/stargazers',
#       'contributors_url': 'https://api.github.com/repos/instacart/radium/contributors',
#       'subscribers_url': 'https://api.github.com/repos/instacart/radium/subscribers',
#       'subscription_url': 'https://api.github.com/repos/instacart/radium/subscription',
#       'commits_url': 'https://api.github.com/repos/instacart/radium/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/instacart/radium/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/instacart/radium/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/instacart/radium/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/instacart/radium/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/instacart/radium/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/instacart/radium/merges',
#       'archive_url': 'https://api.github.com/repos/instacart/radium/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/instacart/radium/downloads',
#       'issues_url': 'https://api.github.com/repos/instacart/radium/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/instacart/radium/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/instacart/radium/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/instacart/radium/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/instacart/radium/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/instacart/radium/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/instacart/radium/deployments',
# ...
#        'repos_url': 'https://api.github.com/users/happo/repos',
#        'events_url': 'https://api.github.com/users/happo/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/happo/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/happo/happo-plugin-storybook',
#       'description': 'A happo.io plugin for Storybook',
#       'fork': False,
#       'url': 'https://api.github.com/repos/happo/happo-plugin-storybook',
#       'forks_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/forks',
#       'keys_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/teams',
#       'hooks_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/hooks',
#       'issue_events_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/events',
#       'assignees_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/tags',
#       'blobs_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/languages',
#       'stargazers_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/stargazers',
#       'contributors_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/contributors',
#       'subscribers_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/subscribers',
#       'subscription_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/subscription',
#       'commits_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/merges',
#       'archive_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/downloads',
#       'issues_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/deployments',
#       'created_at': '2018-06-26T21:04:28Z',
#       'updated_at': '2022-09-28T08:44:17Z',
#       'pushed_at': '2022-11-08T08:35:23Z',
#       'git_url': 'git://github.com/happo/happo-plugin-storybook.git',
#       'ssh_url': 'git@github.com:happo/happo-plugin-storybook.git',
#       'clone_url': 'https://github.com/happo/happo-plugin-storybook.git',
#       'svn_url': 'https://github.com/happo/happo-plugin-storybook',
#       'homepage': None,
#       'size': 1816,
#       'stargazers_count': 10,
#       'watchers_count': 10,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 4,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 10,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 4,
#       'open_issues': 10,
#       'watchers': 10,
#       'default_branch': 'master'}},
#     'base': {'label': 'happo:master',
#      'ref': 'master',
#      'sha': '4a2aad2e63b998fde98fa8da7ec7f20512234574',
#      'user': {'login': 'happo',
#       'id': 31211282,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMxMjExMjgy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/31211282?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/happo',
#       'html_url': 'https://github.com/happo',
#       'followers_url': 'https://api.github.com/users/happo/followers',
#       'following_url': 'https://api.github.com/users/happo/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/happo/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/happo/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/happo/subscriptions',
#       'organizations_url': 'https://api.github.com/users/happo/orgs',
#       'repos_url': 'https://api.github.com/users/happo/repos',
#       'events_url': 'https://api.github.com/users/happo/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/happo/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 138793214,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMzg3OTMyMTQ=',
#       'name': 'happo-plugin-storybook',
#       'full_name': 'happo/happo-plugin-storybook',
#       'private': False,
#       'owner': {'login': 'happo',
#        'id': 31211282,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMxMjExMjgy',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/31211282?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/happo',
#        'html_url': 'https://github.com/happo',
#        'followers_url': 'https://api.github.com/users/happo/followers',
#        'following_url': 'https://api.github.com/users/happo/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/happo/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/happo/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/happo/subscriptions',
#        'organizations_url': 'https://api.github.com/users/happo/orgs',
#        'repos_url': 'https://api.github.com/users/happo/repos',
#        'events_url': 'https://api.github.com/users/happo/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/happo/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/happo/happo-plugin-storybook',
#       'description': 'A happo.io plugin for Storybook',
#       'fork': False,
#       'url': 'https://api.github.com/repos/happo/happo-plugin-storybook',
#       'forks_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/forks',
#       'keys_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/teams',
#       'hooks_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/hooks',
#       'issue_events_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/events',
#       'assignees_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/tags',
#       'blobs_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/languages',
#       'stargazers_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/stargazers',
#       'contributors_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/contributors',
#       'subscribers_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/subscribers',
#       'subscription_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/subscription',
#       'commits_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/merges',
#       'archive_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/downloads',
#       'issues_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/happo/happo-plugin-storybook/deployments',
#       'created_at': '2018-06-26T21:04:28Z',
#       'updated_at': '2022-09-28T08:44:17Z',
#       'pushed_at': '2022-11-08T08:35:23Z',
#       'git_url': 'git://github.com/happo/happo-plugin-storybook.git',
#       'ssh_url': 'git@github.com:happo/happo-plugin-storybook.git',
#       'clone_url': 'https://github.com/happo/happo-plugin-storybook.git',
#       'svn_url': 'https://github.com/happo/happo-plugin-storybook',
#       'homepage': None,
#       'size': 1816,
#       'stargazers_count': 10,
#       'watchers_count': 10,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 4,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 10,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 4,
#       'open_issues': 10,
#       'watchers': 10,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/happo/happo-plugin-storybook/pulls/83'},
#      'html': {'href': 'https://github.com/happo/happo-plugin-storybook/pull/83'},
#      'issue': {'href': 'https://api.github.com/repos/happo/happo-plugin-storybook/issues/83'},
#      'comments': {'href': 'https://api.github.com/repos/happo/happo-plugin-storybook/issues/83/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/happo/happo-plugin-storybook/pulls/83/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/happo/happo-plugin-storybook/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/happo/happo-plugin-storybook/pulls/83/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/happo/happo-plugin-storybook/statuses/3b12d5b3e4ed339c502fe55ba2d5eb9f3bed02f3'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 12,
#     'deletions': 7,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2022-11-08T08:35:23Z',
#   'org': {'id': 31211282,
#    'login': 'happo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/happo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31211282?'}},
#  {'id': '25093616416',
#   'type': 'PushEvent',
#   'actor': {'id': 2687598,
#    'login': 'milesholt',
#    'display_login': 'milesholt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/milesholt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2687598?'},
#   'repo': {'id': 247480564,
#    'name': 'milesholt/autotrade1',
#    'url': 'https://api.github.com/repos/milesholt/autotrade1'},
#   'payload': {'push_id': 11588386628,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/version2',
#    'head': '5182081583193e9b8af47073d8a1c927c0a8ff4f',
#    'before': 'ef9a9316f5457ed28323e7de09a4003a94bbb1d9',
#    'commits': [{'sha': '5182081583193e9b8af47073d8a1c927c0a8ff4f',
#      'author': {'email': 'contact@milesholt.co.uk', 'name': 'milesholt'},
#      'message': 'File updated - November 8, 2022 8:35 AM',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/milesholt/autotrade1/commits/5182081583193e9b8af47073d8a1c927c0a8ff4f'}]},
#   'public': True,
#   'created_at': '2022-11-08T08:35:24Z'},
#  {'id': '25093616426',
#   'type': 'WatchEvent',
#   'actor': {'id': 40284957,
#    'login': 'ningxxOK',
#    'display_login': 'ningxxOK',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ningxxOK',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40284957?'},
#   'repo': {'id': 346279008,
#    'name': 'dgiot/dgiot-dashboard',
#    'url': 'https://api.github.com/repos/dgiot/dgiot-dashboard'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2022-11-08T08:35:24Z',
#   'org': {'id': 49895545,
#    'login': 'dgiot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/dgiot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49895545?'}}]

# %%
pd.DataFrame(response.json())
# Out:
#              id                           type  \
# 0   22197359521                      PushEvent
# 1   22197359525                      PushEvent
# 2   22197359522                      PushEvent
# 3   22197359492                    PublicEvent
# 4   22197359520                      PushEvent
# 5   22197359486                      PushEvent
# 6   22197359494                      PushEvent
# 7   22197359515                      PushEvent
# 8   22197359545  PullRequestReviewCommentEvent
# 9   22197359527                      ForkEvent
# 10  22197359538               PullRequestEvent
# 11  22197359493                      PushEvent
# 12  22197359482                    CreateEvent
# 13  22197359481         PullRequestReviewEvent
# 14  22197359037                      PushEvent
# 15  22197359451                      PushEvent
# 16  22197359455               PullRequestEvent
# 17  22197359441                    DeleteEvent
# 18  22197359449             CommitCommentEvent
# 19  22197359412                      PushEvent
# 20  22197359431               PullRequestEvent
# 21  22197359413                      PushEvent
# 22  22197359401                      ForkEvent
# 23  22197359410                    MemberEvent
# 24  22197359427                    CreateEvent
# 25  22197359436                    CreateEvent
# 26  22197359421  PullRequestReviewCommentEvent
# 27  22197359405                    CreateEvent
# 28  22197359396                      PushEvent
# 29  22197359341                      PushEvent
#
#                                                 actor  \
# 0   {'id': 105903627, 'login': 'clarisslee', 'disp...
# 1   {'id': 9946257, 'login': 'roigagusti', 'displa...
# 2   {'id': 41898282, 'login': 'github-actions[bot]...
# 3   {'id': 19181295, 'login': 'ArunYogeshwaran', '...
# 4   {'id': 81509342, 'login': 'Rakesh-swain', 'dis...
# 5   {'id': 27484282, 'login': 'alex-toy', 'display...
# 6   {'id': 41898282, 'login': 'github-actions[bot]...
# 7   {'id': 37245346, 'login': 'jvo203', 'display_l...
# 8   {'id': 17219438, 'login': 'fengyuentau', 'disp...
# 9   {'id': 84961041, 'login': 'Ethenwilde', 'displ...
# 10  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 11  {'id': 45653647, 'login': 'OnlineHacKing', 'di...
# 12  {'id': 100225125, 'login': 'fkartal47', 'displ...
# 13  {'id': 17219438, 'login': 'fengyuentau', 'disp...
# 14  {'id': 39732517, 'login': 'Freymaurer', 'displ...
# 15  {'id': 33259379, 'login': 'eryajf', 'display_l...
# 16  {'id': 4921914, 'login': 'csouchet', 'display_...
# 17  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 18  {'id': 35613825, 'login': 'vercel[bot]', 'disp...
# 19  {'id': 93227343, 'login': 'tf-vcs-testing', 'd...
# 20  {'id': 6938205, 'login': 'dimsa', 'display_log...
# 21  {'id': 98041731, 'login': 'lethuandat', 'displ...
# 22  {'id': 107031185, 'login': 'RishabhHariyale', ...
# 23  {'id': 96527006, 'login': 'kimtaehoon222', 'di...
# 24  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 25  {'id': 102762865, 'login': 'Johnrhume', 'displ...
# 26  {'id': 12039224, 'login': 'rzadp', 'display_lo...
# 27  {'id': 44988050, 'login': 'matthewleyden7', 'd...
# 28  {'id': 42643859, 'login': 'cayop', 'display_lo...
# 29  {'id': 71113305, 'login': 'kyaxeli', 'display_...
#
#                                                  repo  \
# 0   {'id': 498151358, 'name': 'isomerpages/moe-buk...
# 1   {'id': 499524524, 'name': 'roigagusti/rompefli...
# 2   {'id': 447145720, 'name': 'hicccup/AG', 'url':...
# 3   {'id': 254922182, 'name': 'ArunYogeshwaran/cor...
# 4   {'id': 498547745, 'name': 'Rakesh-swain/flutte...
# 5   {'id': 500743913, 'name': 'alex-toy/SettingUpA...
# 6   {'id': 453539056, 'name': 'fdciabdul/Google-Tr...
# 7   {'id': 326086306, 'name': 'jvo203/FITSWEBQLSE'...
# 8   {'id': 493293777, 'name': 'opencv/ci-gha-workf...
# 9   {'id': 395634044, 'name': 'celiakwan/ethereum-...
# 10  {'id': 130399182, 'name': 'olekenneth/pyXcomfo...
# 11  {'id': 344723338, 'name': 'OnlineHacKing/FreeF...
# 12  {'id': 500748401, 'name': 'fkartal47/Appium', ...
# 13  {'id': 493293777, 'name': 'opencv/ci-gha-workf...
# 14  {'id': 438547040, 'name': 'nfdi4plants/web-com...
# 15  {'id': 498150719, 'name': 'eryajf/learn-github...
# 16  {'id': 373825517, 'name': 'process-analytics/p...
# 17  {'id': 332782803, 'name': 'DavidSpek/crd-valid...
# 18  {'id': 235538333, 'name': 'maael/temtem-api', ...
# 19  {'id': 500748121, 'name': 'tf-vcs-e2e/e2e-gh-a...
# 20  {'id': 195480881, 'name': 'aspose-psd/Aspose.P...
# 21  {'id': 488906552, 'name': 'lethuandat/module2'...
# 22  {'id': 500434779, 'name': 'DSHP-tc/Tuffle-Fees...
# 23  {'id': 500738156, 'name': 'kimtaehoon222/final...
# 24  {'id': 130399182, 'name': 'olekenneth/pyXcomfo...
# 25  {'id': 500748400, 'name': 'Johnrhume/Future-Ca...
# 26  {'id': 322542582, 'name': 'TrueFiEng/useDApp',...
# 27  {'id': 500741250, 'name': 'matthewleyden7/N-Po...
# 28  {'id': 128951719, 'name': 'eReuse/devicehub-te...
# 29  {'id': 500633318, 'name': 'kyaxeli/Heritage-Ho...
#
#                                               payload  public  \
# 0   {'push_id': 10090507973, 'size': 1, 'distinct_...    True
# 1   {'push_id': 10090507942, 'size': 1, 'distinct_...    True
# 2   {'push_id': 10090507958, 'size': 1, 'distinct_...    True
# 3                                                  {}    True
# 4   {'push_id': 10090507960, 'size': 1, 'distinct_...    True
# 5   {'push_id': 10090507933, 'size': 1, 'distinct_...    True
# 6   {'push_id': 10090507934, 'size': 1, 'distinct_...    True
# 7   {'push_id': 10090507944, 'size': 1, 'distinct_...    True
# 8   {'action': 'created', 'comment': {'url': 'http...    True
# 9   {'forkee': {'id': 500748403, 'node_id': 'R_kgD...    True
# 10  {'action': 'opened', 'number': 93, 'pull_reque...    True
# 11  {'push_id': 10090507950, 'size': 1, 'distinct_...    True
# 12  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 13  {'action': 'created', 'review': {'id': 9977025...    True
# 14  {'push_id': 10090507732, 'size': 1, 'distinct_...    True
# 15  {'push_id': 10090507928, 'size': 1, 'distinct_...    True
# 16  {'action': 'closed', 'number': 536, 'pull_requ...    True
# 17  {'ref': 'dependabot/go_modules/vendor/github.c...    True
# 18  {'comment': {'url': 'https://api.github.com/re...    True
# 19  {'push_id': 10090507918, 'size': 1, 'distinct_...    True
# 20  {'action': 'closed', 'number': 8, 'pull_reques...    True
# 21  {'push_id': 10090507919, 'size': 1, 'distinct_...    True
# 22  {'forkee': {'id': 500748399, 'node_id': 'R_kgD...    True
# 23  {'member': {'login': 'blair-js', 'id': 8150240...    True
# 24  {'ref': 'dependabot/pip/pylint-2.14.1', 'ref_t...    True
# 25  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 26  {'action': 'created', 'comment': {'url': 'http...    True
# 27  {'ref': 'gh-pages', 'ref_type': 'branch', 'mas...    True
# 28  {'push_id': 10090507874, 'size': 2, 'distinct_...    True
# 29  {'push_id': 10090507883, 'size': 1, 'distinct_...    True
#
#               created_at                                                org
# 0   2022-06-07T08:11:37Z  {'id': 40887764, 'login': 'isomerpages', 'grav...
# 1   2022-06-07T08:11:37Z                                                NaN
# 2   2022-06-07T08:11:37Z                                                NaN
# 3   2022-06-07T08:11:37Z                                                NaN
# 4   2022-06-07T08:11:37Z                                                NaN
# 5   2022-06-07T08:11:37Z                                                NaN
# 6   2022-06-07T08:11:37Z                                                NaN
# 7   2022-06-07T08:11:37Z                                                NaN
# 8   2022-06-07T08:11:36Z  {'id': 5009934, 'login': 'opencv', 'gravatar_i...
# 9   2022-06-07T08:11:37Z                                                NaN
# 10  2022-06-07T08:11:37Z                                                NaN
# 11  2022-06-07T08:11:37Z                                                NaN
# 12  2022-06-07T08:11:37Z                                                NaN
# 13  2022-06-07T08:11:37Z  {'id': 5009934, 'login': 'opencv', 'gravatar_i...
# 14  2022-06-07T08:11:36Z  {'id': 65858056, 'login': 'nfdi4plants', 'grav...
# 15  2022-06-07T08:11:37Z                                                NaN
# 16  2022-06-07T08:11:37Z  {'id': 60110287, 'login': 'process-analytics',...
# 17  2022-06-07T08:11:37Z                                                NaN
# 18  2022-06-07T08:11:37Z                                                NaN
# 19  2022-06-07T08:11:37Z  {'id': 94930388, 'login': 'tf-vcs-e2e', 'grava...
# 20  2022-06-07T08:11:37Z  {'id': 40893524, 'login': 'aspose-psd', 'grava...
# 21  2022-06-07T08:11:37Z                                                NaN
# 22  2022-06-07T08:11:37Z                                                NaN
# 23  2022-06-07T08:11:37Z                                                NaN
# 24  2022-06-07T08:11:37Z                                                NaN
# 25  2022-06-07T08:11:37Z                                                NaN
# 26  2022-06-07T08:11:32Z  {'id': 100762633, 'login': 'TrueFiEng', 'grava...
# 27  2022-06-07T08:11:37Z                                                NaN
# 28  2022-06-07T08:11:37Z  {'id': 11991898, 'login': 'eReuse', 'gravatar_...
# 29  2022-06-07T08:11:37Z                                                NaN

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id                           type  public            created_at  \
# 0   22197359521                      PushEvent    True  2022-06-07T08:11:37Z
# 1   22197359525                      PushEvent    True  2022-06-07T08:11:37Z
# 2   22197359522                      PushEvent    True  2022-06-07T08:11:37Z
# 3   22197359492                    PublicEvent    True  2022-06-07T08:11:37Z
# 4   22197359520                      PushEvent    True  2022-06-07T08:11:37Z
# 5   22197359486                      PushEvent    True  2022-06-07T08:11:37Z
# 6   22197359494                      PushEvent    True  2022-06-07T08:11:37Z
# 7   22197359515                      PushEvent    True  2022-06-07T08:11:37Z
# 8   22197359545  PullRequestReviewCommentEvent    True  2022-06-07T08:11:36Z
# 9   22197359527                      ForkEvent    True  2022-06-07T08:11:37Z
# 10  22197359538               PullRequestEvent    True  2022-06-07T08:11:37Z
# 11  22197359493                      PushEvent    True  2022-06-07T08:11:37Z
# 12  22197359482                    CreateEvent    True  2022-06-07T08:11:37Z
# 13  22197359481         PullRequestReviewEvent    True  2022-06-07T08:11:37Z
# 14  22197359037                      PushEvent    True  2022-06-07T08:11:36Z
# 15  22197359451                      PushEvent    True  2022-06-07T08:11:37Z
# 16  22197359455               PullRequestEvent    True  2022-06-07T08:11:37Z
# 17  22197359441                    DeleteEvent    True  2022-06-07T08:11:37Z
# 18  22197359449             CommitCommentEvent    True  2022-06-07T08:11:37Z
# 19  22197359412                      PushEvent    True  2022-06-07T08:11:37Z
# 20  22197359431               PullRequestEvent    True  2022-06-07T08:11:37Z
# 21  22197359413                      PushEvent    True  2022-06-07T08:11:37Z
# 22  22197359401                      ForkEvent    True  2022-06-07T08:11:37Z
# 23  22197359410                    MemberEvent    True  2022-06-07T08:11:37Z
# 24  22197359427                    CreateEvent    True  2022-06-07T08:11:37Z
# 25  22197359436                    CreateEvent    True  2022-06-07T08:11:37Z
# 26  22197359421  PullRequestReviewCommentEvent    True  2022-06-07T08:11:32Z
# 27  22197359405                    CreateEvent    True  2022-06-07T08:11:37Z
# 28  22197359396                      PushEvent    True  2022-06-07T08:11:37Z
# 29  22197359341                      PushEvent    True  2022-06-07T08:11:37Z
#
#      actor.id          actor.login actor.display_login actor.gravatar_id  \
# 0   105903627           clarisslee          clarisslee
# 1     9946257           roigagusti          roigagusti
# 2    41898282  github-actions[bot]      github-actions
# 3    19181295      ArunYogeshwaran     ArunYogeshwaran
# 4    81509342         Rakesh-swain        Rakesh-swain
# 5    27484282             alex-toy            alex-toy
# 6    41898282  github-actions[bot]      github-actions
# 7    37245346               jvo203              jvo203
# 8    17219438          fengyuentau         fengyuentau
# 9    84961041           Ethenwilde          Ethenwilde
# 10   49699333      dependabot[bot]          dependabot
# 11   45653647        OnlineHacKing       OnlineHacKing
# 12  100225125            fkartal47           fkartal47
# 13   17219438          fengyuentau         fengyuentau
# 14   39732517           Freymaurer          Freymaurer
# 15   33259379               eryajf              eryajf
# 16    4921914             csouchet            csouchet
# 17   49699333      dependabot[bot]          dependabot
# 18   35613825          vercel[bot]              vercel
# 19   93227343       tf-vcs-testing      tf-vcs-testing
# 20    6938205                dimsa               dimsa
# 21   98041731           lethuandat          lethuandat
# 22  107031185      RishabhHariyale     RishabhHariyale
# 23   96527006        kimtaehoon222       kimtaehoon222
# 24   49699333      dependabot[bot]          dependabot
# 25  102762865            Johnrhume           Johnrhume
# 26   12039224                rzadp               rzadp
# 27   44988050       matthewleyden7      matthewleyden7
# 28   42643859                cayop               cayop
# 29   71113305              kyaxeli             kyaxeli
#
#                                            actor.url  \
# 0            https://api.github.com/users/clarisslee
# 1            https://api.github.com/users/roigagusti
# 2   https://api.github.com/users/github-actions[bot]
# 3       https://api.github.com/users/ArunYogeshwaran
# 4          https://api.github.com/users/Rakesh-swain
# 5              https://api.github.com/users/alex-toy
# 6   https://api.github.com/users/github-actions[bot]
# 7                https://api.github.com/users/jvo203
# 8           https://api.github.com/users/fengyuentau
# 9            https://api.github.com/users/Ethenwilde
# 10      https://api.github.com/users/dependabot[bot]
# 11        https://api.github.com/users/OnlineHacKing
# 12            https://api.github.com/users/fkartal47
# 13          https://api.github.com/users/fengyuentau
# 14           https://api.github.com/users/Freymaurer
# 15               https://api.github.com/users/eryajf
# 16             https://api.github.com/users/csouchet
# 17      https://api.github.com/users/dependabot[bot]
# 18          https://api.github.com/users/vercel[bot]
# 19       https://api.github.com/users/tf-vcs-testing
# 20                https://api.github.com/users/dimsa
# 21           https://api.github.com/users/lethuandat
# 22      https://api.github.com/users/RishabhHariyale
# 23        https://api.github.com/users/kimtaehoon222
# 24      https://api.github.com/users/dependabot[bot]
# 25            https://api.github.com/users/Johnrhume
# 26                https://api.github.com/users/rzadp
# 27       https://api.github.com/users/matthewleyden7
# 28                https://api.github.com/users/cayop
# 29              https://api.github.com/users/kyaxeli
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/105903...  ...
# 1    https://avatars.githubusercontent.com/u/9946257?  ...
# 2   https://avatars.githubusercontent.com/u/41898282?  ...
# 3   https://avatars.githubusercontent.com/u/19181295?  ...
# 4   https://avatars.githubusercontent.com/u/81509342?  ...
# 5   https://avatars.githubusercontent.com/u/27484282?  ...
# 6   https://avatars.githubusercontent.com/u/41898282?  ...
# 7   https://avatars.githubusercontent.com/u/37245346?  ...
# 8   https://avatars.githubusercontent.com/u/17219438?  ...
# 9   https://avatars.githubusercontent.com/u/84961041?  ...
# 10  https://avatars.githubusercontent.com/u/49699333?  ...
# 11  https://avatars.githubusercontent.com/u/45653647?  ...
# 12  https://avatars.githubusercontent.com/u/100225...  ...
# 13  https://avatars.githubusercontent.com/u/17219438?  ...
# 14  https://avatars.githubusercontent.com/u/39732517?  ...
# 15  https://avatars.githubusercontent.com/u/33259379?  ...
# 16   https://avatars.githubusercontent.com/u/4921914?  ...
# 17  https://avatars.githubusercontent.com/u/49699333?  ...
# 18  https://avatars.githubusercontent.com/u/35613825?  ...
# 19  https://avatars.githubusercontent.com/u/93227343?  ...
# 20   https://avatars.githubusercontent.com/u/6938205?  ...
# 21  https://avatars.githubusercontent.com/u/98041731?  ...
# 22  https://avatars.githubusercontent.com/u/107031...  ...
# 23  https://avatars.githubusercontent.com/u/96527006?  ...
# 24  https://avatars.githubusercontent.com/u/49699333?  ...
# 25  https://avatars.githubusercontent.com/u/102762...  ...
# 26  https://avatars.githubusercontent.com/u/12039224?  ...
# 27  https://avatars.githubusercontent.com/u/44988050?  ...
# 28  https://avatars.githubusercontent.com/u/42643859?  ...
# 29  https://avatars.githubusercontent.com/u/71113305?  ...
#
#                          payload.member.following_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  https://api.github.com/users/blair-js/followin...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                              payload.member.gists_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  https://api.github.com/users/blair-js/gists{/g...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                            payload.member.starred_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  https://api.github.com/users/blair-js/starred{...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                      payload.member.subscriptions_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  https://api.github.com/users/blair-js/subscrip...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#               payload.member.organizations_url  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23  https://api.github.com/users/blair-js/orgs
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29                                         NaN
#
#                        payload.member.repos_url  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23  https://api.github.com/users/blair-js/repos
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
#
#                             payload.member.events_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  https://api.github.com/users/blair-js/events{/...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                    payload.member.received_events_url payload.member.type  \
# 0                                                 NaN                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
# 5                                                 NaN                 NaN
# 6                                                 NaN                 NaN
# 7                                                 NaN                 NaN
# 8                                                 NaN                 NaN
# 9                                                 NaN                 NaN
# 10                                                NaN                 NaN
# 11                                                NaN                 NaN
# 12                                                NaN                 NaN
# 13                                                NaN                 NaN
# 14                                                NaN                 NaN
# 15                                                NaN                 NaN
# 16                                                NaN                 NaN
# 17                                                NaN                 NaN
# 18                                                NaN                 NaN
# 19                                                NaN                 NaN
# 20                                                NaN                 NaN
# 21                                                NaN                 NaN
# 22                                                NaN                 NaN
# 23  https://api.github.com/users/blair-js/received...                User
# 24                                                NaN                 NaN
# 25                                                NaN                 NaN
# 26                                                NaN                 NaN
# 27                                                NaN                 NaN
# 28                                                NaN                 NaN
# 29                                                NaN                 NaN
#
#    payload.member.site_admin
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                     False
# 24                       NaN
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
#
# [30 rows x 578 columns]

# %% [markdown]
# ### International Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'timestamp': 1667897317,
#  'message': 'success',
#  'iss_position': {'latitude': '48.8211', 'longitude': '-82.1931'}}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack
coordinates = {"lat": 41.397730, "lon": 2.190290}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 404

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=41.39773&lon=2.19029'

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json?lat=41.39773&lon=2.19029")

# %%
response.status_code
# Out:
# 404

# %%
#response.json()

# %%
from datetime import datetime
datetime.fromtimestamp(1604442746)
# Out:
# datetime.datetime(2020, 11, 3, 23, 32, 26)

# %%
pd.to_datetime(1604442746, unit="s",)
# Out:
# Timestamp('2020-11-03 22:32:26')

# %% [markdown]
# ### Weather API
#
# Create an account at RapidAPI and "subscribe" to the Weather API: https://rapidapi.com/weatherbit/api/

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/current"

#My location coords: lat: 40.545111, lon: -4.204942
querystring = {"lon":"-4.204942","lat":"40.545111"}
querystring["units"] ="metric"
querystring["lang"] = "en"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request('GET', url, headers=headers, params=querystring)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [17], line 11
#       7 querystring["units"] ="metric"
#       8 querystring["lang"] = "en"
#      10 headers = {
# ---> 11     'x-rapidapi-key': x_rapidapi_key,
#      12     'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
#      13     }
#      15 response = requests.request("GET", url, headers=headers, params=querystring)
#      17 print(response.text)
#
# NameError: name 'x_rapidapi_key' is not defined

# %%
response.url
# Out:
# 'https://weatherbit-v1-mashape.p.rapidapi.com/current?lon=-4.204942&lat=40.545111&units=metric&lang=en'

# %%
results = response.json()
print(results)
type(results)
# Out:
# {'data': [{'rh': 42, 'pod': 'd', 'lon': -4.2, 'pres': 884.671, 'timezone': 'Europe/Madrid', 'ob_time': '2022-06-07 08:15', 'country_code': 'ES', 'clouds': 0, 'ts': 1654589700, 'solar_rad': 542, 'state_code': '29', 'city_name': 'Zarzalejo', 'wind_spd': 1.26768, 'wind_cdir_full': 'south-southwest', 'wind_cdir': 'SSW', 'slp': 1019.99, 'vis': 16, 'h_angle': -45, 'sunset': '19:44', 'dni': 809.68, 'dewpt': 10.9, 'snow': 0, 'uv': 3.78599, 'precip': 0, 'wind_dir': 192, 'sunrise': '04:45', 'ghi': 542.03, 'dhi': 92.68, 'aqi': 29, 'lat': 40.55, 'weather': {'icon': 'c01d', 'code': 800, 'description': 'Clear sky'}, 'datetime': '2022-06-07:08', 'temp': 24.4, 'station': 'F7959', 'elev_angle': 34.19, 'app_temp': 24}], 'count': 1}
# dict

# %%
results.keys()
# Out:
# dict_keys(['data', 'count'])

# %%
results['data']
# Out:
# [{'app_temp': 24,
#   'aqi': 29,
#   'city_name': 'Zarzalejo',
#   'clouds': 0,
#   'country_code': 'ES',
#   'datetime': '2022-06-07:08',
#   'dewpt': 10.9,
#   'dhi': 92.68,
#   'dni': 809.68,
#   'elev_angle': 34.19,
#   'ghi': 542.03,
#   'h_angle': -45,
#   'lat': 40.55,
#   'lon': -4.2,
#   'ob_time': '2022-06-07 08:15',
#   'pod': 'd',
#   'precip': 0,
#   'pres': 884.671,
#   'rh': 42,
#   'slp': 1019.99,
#   'snow': 0,
#   'solar_rad': 542,
#   'state_code': '29',
#   'station': 'F7959',
#   'sunrise': '04:45',
#   'sunset': '19:44',
#   'temp': 24.4,
#   'timezone': 'Europe/Madrid',
#   'ts': 1654589700,
#   'uv': 3.78599,
#   'vis': 16,
#   'weather': {'code': 800, 'description': 'Clear sky', 'icon': 'c01d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 192,
#   'wind_spd': 1.26768}]

# %% [markdown]
# Getting the forecast for the next 5 days at a 3h intervals

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/3hourly"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
results = response.json()
print(results)
# Out:
# {'data': [{'wind_cdir': 'SSW', 'rh': 43, 'pod': 'd', 'timestamp_utc': '2022-06-07T09:00:00', 'pres': 884.7, 'solar_rad': 718.33, 'ozone': 305.8, 'weather': {'icon': 'c01d', 'code': 800, 'description': 'Clear Sky'}, 'wind_gust_spd': 3.88, 'timestamp_local': '2022-06-07T11:00:00', 'snow_depth': 0, 'clouds': 0, 'ts': 1654592400, 'wind_spd': 1.27, 'pop': 0, 'wind_cdir_full': 'south-southwest', 'slp': 1020, 'dni': 870.27, 'dewpt': 9, 'snow': 0, 'uv': 5.5, 'wind_dir': 192, 'clouds_hi': 4, 'precip': 0, 'vis': 24.128, 'dhi': 103.59, 'app_temp': 21.6, 'datetime': '2022-06-07:09', 'temp': 22.2, 'ghi': 718.33, 'clouds_mid': 0, 'clouds_low': 0}, {'wind_cdir': 'SSW', 'rh': 34, 'pod': 'd', 'timestamp_utc': '2022-06-07T12:00:00', 'pres': 883.7, 'solar_rad': 1001.48, 'ozone': 304.8, 'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 6.14, 'timestamp_local': '2022-06-07T14:00:00', 'snow_depth': 0, 'clouds': 8, 'ts': 1654603200, 'wind_spd': 2.73, 'pop': 0, 'wind_cdir_full': 'south-southwest', 'slp': 1018.1, 'dni': 938.95, 'dewpt': 9.3, 'snow': 0, 'uv': 9.7, 'wind_dir': 196, 'clouds_hi': 65, 'precip': 0, 'vis': 24.128, 'dhi': 117.69, 'app_temp': 26, 'datetime': '2022-06-07:12', 'temp': 26.4, 'ghi': 1001.65, 'clouds_mid': 0, 'clouds_low': 51}, {'wind_cdir': 'SW', 'rh': 28, 'pod': 'd', 'timestamp_utc': '2022-06-07T15:00:00', 'pres': 881.9, 'solar_rad': 765.955, 'ozone': 301, 'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 7.22, 'timestamp_local': '2022-06-07T17:00:00', 'snow_depth': 0, 'clouds': 39, 'ts': 1654614000, 'wind_spd': 3.3, 'pop': 0, 'wind_cdir_full': 'southwest', 'slp': 1015.4, 'dni': 891.6, 'dewpt': 7.7, 'snow': 0, 'uv': 4.8, 'wind_dir': 236, 'clouds_hi': 49, 'precip': 0, 'vis': 24.128, 'dhi': 107.75, 'app_temp': 26.9, 'datetime': '2022-06-07:15', 'temp': 27.9, 'ghi': 795.08, 'clouds_mid': 68, 'clouds_low': 2}, {'wind_cdir': 'NW', 'rh': 33, 'pod': 'd', 'timestamp_utc': '2022-06-07T18:00:00', 'pres': 881, 'solar_rad': 252.57, 'ozone': 297, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 8.54, 'timestamp_local': '2022-06-07T20:00:00', 'snow_depth': 0, 'clouds': 0, 'ts': 1654624800, 'wind_spd': 3.54, 'pop': 0, 'wind_cdir_full': 'northwest', 'slp': 1014.6, 'dni': 639.04, 'dewpt': 8.2, 'snow': 0, 'uv': 1.8, 'wind_dir': 325, 'clouds_hi': 0, 'precip': 0, 'vis': 24.128, 'dhi': 67.62, 'app_temp': 25.1, 'datetime': '2022-06-07:18', 'temp': 25.6, 'ghi': 252.57, 'clouds_mid': 42, 'clouds_low': 8}, {'wind_cdir': 'NW', 'rh': 25, 'pod': 'n', 'timestamp_utc': '2022-06-07T21:00:00', 'pres': 881.9, 'solar_rad': 0, 'ozone': 298.8, 'weather': {'icon': 'c01n', 'code': 800, 'description': 'Clear Sky'}, 'wind_gust_spd': 10.77, 'timestamp_local': '2022-06-07T23:00:00', 'snow_depth': 0, 'clouds': 0, 'ts': 1654635600, 'wind_spd': 3.06, 'pop': 0, 'wind_cdir_full': 'northwest', 'slp': 1016.3, 'dni': 0, 'dewpt': 1, 'snow': 0, 'uv': 0, 'wind_dir': 324, 'clouds_hi': 0, 'precip': 0, 'vis': 24.128, 'dhi': 0, 'app_temp': 20.8, 'datetime': '2022-06-07:21', 'temp': 21.9, 'ghi': 0, 'clouds_mid': 0, 'clouds_low': 0}, {'wind_cdir': 'NNW', 'rh': 50, 'pod': 'n', 'timestamp_utc': '2022-06-08T00:00:00', 'pres': 881.2, 'solar_rad': 0, 'ozone': 298.3, 'weather': {'icon': 'c02n', 'code': 801, 'description': 'Few clouds'}, 'wind_gust_spd': 19.1, 'timestamp_local': '2022-06-08T02:00:00', 'snow_depth': 0, 'clouds': 1, 'ts': 1654646400, 'wind_spd': 4.7, 'pop': 0, 'wind_cdir_full': 'north-northwest', 'slp': 1016.3, 'dni': 0, 'dewpt': 8.4, 'snow': 0, 'uv': 0, 'wind_dir': 330, 'clouds_hi': 33, 'precip': 0, 'vis': 24.128, 'dhi': 0, 'app_temp': 18.4, 'datetime': '2022-06-08:00', 'temp': 19.1, 'ghi': 0, 'clouds_mid': 0, 'clouds_low': 0}, {'wind_cdir': 'NNW', 'rh': 58, 'pod': 'n', 'timestamp_utc': '2022-06-08T03:00:00', 'pres': 880.9, 'solar_rad': 0, 'ozone': 297.5, 'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 12. ...

# %%
results['data']
# Out:
# [{'app_temp': 21.6,
#   'clouds': 0,
#   'clouds_hi': 4,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-07:09',
#   'dewpt': 9,
#   'dhi': 103.59,
#   'dni': 870.27,
#   'ghi': 718.33,
#   'ozone': 305.8,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 884.7,
#   'rh': 43,
#   'slp': 1020,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 718.33,
#   'temp': 22.2,
#   'timestamp_local': '2022-06-07T11:00:00',
#   'timestamp_utc': '2022-06-07T09:00:00',
#   'ts': 1654592400,
#   'uv': 5.5,
#   'vis': 24.128,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 192,
#   'wind_gust_spd': 3.88,
#   'wind_spd': 1.27},
#  {'app_temp': 26,
#   'clouds': 8,
#   'clouds_hi': 65,
#   'clouds_low': 51,
#   'clouds_mid': 0,
#   'datetime': '2022-06-07:12',
#   'dewpt': 9.3,
#   'dhi': 117.69,
#   'dni': 938.95,
#   'ghi': 1001.65,
#   'ozone': 304.8,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 883.7,
#   'rh': 34,
#   'slp': 1018.1,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 1001.48,
#   'temp': 26.4,
#   'timestamp_local': '2022-06-07T14:00:00',
#   'timestamp_utc': '2022-06-07T12:00:00',
#   'ts': 1654603200,
#   'uv': 9.7,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 196,
#   'wind_gust_spd': 6.14,
#   'wind_spd': 2.73},
#  {'app_temp': 26.9,
#   'clouds': 39,
#   'clouds_hi': 49,
#   'clouds_low': 2,
#   'clouds_mid': 68,
#   'datetime': '2022-06-07:15',
#   'dewpt': 7.7,
#   'dhi': 107.75,
#   'dni': 891.6,
#   'ghi': 795.08,
#   'ozone': 301,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 881.9,
#   'rh': 28,
#   'slp': 1015.4,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 765.955,
#   'temp': 27.9,
#   'timestamp_local': '2022-06-07T17:00:00',
#   'timestamp_utc': '2022-06-07T15:00:00',
#   'ts': 1654614000,
#   'uv': 4.8,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SW',
#   'wind_cdir_full': 'southwest',
#   'wind_dir': 236,
#   'wind_gust_spd': 7.22,
#   'wind_spd': 3.3},
#  {'app_temp': 25.1,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 8,
#   'clouds_mid': 42,
#   'datetime': '2022-06-07:18',
#   'dewpt': 8.2,
#   'dhi': 67.62,
#   'dni': 639.04,
#   'ghi': 252.57,
#   'ozone': 297,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 881,
#   'rh': 33,
#   'slp': 1014.6,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 252.57,
#   'temp': 25.6,
#   'timestamp_local': '2022-06-07T20:00:00',
#   'timestamp_utc': '2022-06-07T18:00:00',
#   'ts': 1654624800,
#   'uv': 1.8,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NW',
#   'wind_cdir_full': 'northwest',
#   'wind_dir': 325,
#   'wind_gust_spd': 8.54,
#   'wind_spd': 3.54},
#  {'app_temp': 20.8,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-07:21',
#   'dewpt': 1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 298.8,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 881.9,
#   'rh': 25,
#   'slp': 1016.3,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 21.9,
#   'timestamp_local': '2022-06-07T23:00:00',
#   'timestamp_utc': '2022-06-07T21:00:00',
#   'ts': 1654635600,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#   'wind_cdir': 'NW',
#   'wind_cdir_full': 'northwest',
#   'wind_dir': 324,
#   'wind_gust_spd': 10.77,
#   'wind_spd': 3.06},
#  {'app_temp': 18.4,
#   'clouds': 1,
#   'clouds_hi': 33,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-08:00',
#   'dewpt': 8.4,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 298.3,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 881.2,
#   'rh': 50,
#   'slp': 1016.3,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 19.1,
#   'timestamp_local': '2022-06-08T02:00:00',
#   'timestamp_utc': '2022-06-08T00:00:00',
#   'ts': 1654646400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 330,
#   'wind_gust_spd': 19.1,
#   'wind_spd': 4.7},
#  {'app_temp': 17.6,
#   'clouds': 35,
#   'clouds_hi': 100,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-08:03',
#   'dewpt': 9.3,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 297.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 880.9,
#   'rh': 58,
#   'slp': 1016.3,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 17.6,
#   'timestamp_local': '2022-06-08T05:00:00',
#   'timestamp_utc': '2022-06-08T03:00:00',
#   'ts': 1654657200,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 335,
#   'wind_gust_spd': 12.26,
#   'wind_spd': 3.67},
#  {'app_temp': 16.8,
#   'clouds': 43,
#   'clouds_hi': 98,
#   'clouds_low': 1,
#   'clouds_mid': 0,
#   'datetime': '2022-06-08:06',
#   'dewpt': 9.5,
#   'dhi': 55.48,
#   'dni': 536.81,
#   'ghi': 159.84,
#   'ozone': 300.8,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 881.1,
#   'rh': 62,
#   'slp': 1016.9,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 151.679,
#   'temp': 16.8,
#   'timestamp_local': '2022-06-08T08:00:00',
#   'timestamp_utc': '2022-06-08T06:00:00',
#   'ts': 1654668000,
#   'uv': 1.1,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 334,
#   'wind_gust_spd': 12.58,
#   'wind_spd': 3.23},
#  {'app_temp': 19.9,
#   'clouds': 26,
#   'clouds_hi': 89,
#   'clouds_low': 11,
#   'clouds_mid': 0,
#   'datetime': '2022-06-08:09',
#   'dewpt': 10.7,
#   'dhi': 103.58,
#   'dni': 870.13,
#   'ghi': 718.39,
#   'ozone': 302.3,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 881.9,
#   'rh': 54,
#   'slp': 1017.3,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 689.413,
#   'temp': 20.4,
#   'timestamp_local': '2022-06-08T11:00:00',
#   'timestamp_utc': '2022-06-08T09:00:00',
#   'ts': 1654678800,
#   'uv': 4.5,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 333,
#   'wind_gust_spd': 13.41,
#   'wind_spd': 4.65},
#  {'app_temp': 22.8,
#   'clouds': 29,
#   'clouds_hi': 100,
#   'clouds_low': 16,
#   'clouds_mid': 0,
#   'datetime': '2022-06-08:12',
#   'dewpt': 10.7,
#   'dhi': 117.68,
#   'dni': 938.83,
#   'ghi': 1001.94,
#   'ozone': 302.5,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 882.1,
#   'rh': 45,
#   'slp': 1016.9,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 958.026,
#   'temp': 23.3,
#   'timestamp_local': '2022-06-08T14:00:00',
#   'timestamp_utc': '2022-06-08T12:00:00',
#   'ts': 1654689600,
#   'uv': 8.2,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'NW',
#   'wind_cdir_full': 'northwest',
#   'wind_dir': 326,
#   'wind_gust_spd': 14.48,
#   'wind_spd': 6.52},
#  {'app_temp': 24.6,
#   'clouds': 10,
#   'clouds_hi': 100,
#   'clouds_low': 18,
#   'clouds_mid': 43,
#   'datetime': '2022-06-08:15',
#   'dewpt': 9.8,
#   'dhi': 107.79,
#   'dni': 891.69,
#   'ghi': 796.04,
#   'ozone': 302.3,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 881.9,
#   'rh': 38,
#   'slp': 1016.1,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 795.755,
#   'temp': 25.1,
#   'timestamp_local': '2022-06-08T17:00:00',
#   'timestamp_utc': '2022-06-08T15:00:00',
#   'ts': 1654700400,
#   'uv': 6.1,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'NW',
#   'wind_cdir_full': 'northwest',
#   'wind_dir': 323,
#   'wind_gust_spd': 12.94,
#   'wind_spd': 5.83},
#  {'app_temp': 22.7,
#   'clouds': 0,
#   'clouds_hi': 53,
#   'clouds_low': 11,
#   'clouds_mid': 24,
#   'datetime': '2022-06-08:18',
#   'dewpt': 10.2,
#   'dhi': 67.77,
#   'dni': 640.25,
#   'ghi': 254.04,
#   'ozone': 300.3,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 881.6,
#   'rh': 44,
#   'slp': 1016,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 254.04,
#   'temp': 23.1,
#   'timestamp_local': '2022-06-08T20:00:00',
#   'timestamp_utc': '2022-06-08T18:00:00',
#   'ts': 1654711200,
#   'uv': 1.8,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 328,
#   'wind_gust_spd': 12.96,
#   'wind_spd': 6.28},
#  {'app_temp': 19.5,
#   'clouds': 0,
#   'clouds_hi': 16,
#   'clouds_low': 1,
#   'clouds_mid': 11,
#   'datetime': '2022-06-08:21',
#   'dewpt': 10.7,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 300.3,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 883,
#   'rh': 55,
#   'slp': 1018.2,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 20,
#   'timestamp_local': '2022-06-08T23:00:00',
#   'timestamp_utc': '2022-06-08T21:00:00',
#   'ts': 1654722000,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 337,
#   'wind_gust_spd': 20.87,
#   'wind_spd': 6.55},
#  {'app_temp': 17.9,
#   'clouds': 6,
#   'clouds_hi': 61,
#   'clouds_low': 12,
#   'clouds_mid': 3,
#   'datetime': '2022-06-09:00',
#   'dewpt': 10.3,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 297.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 883.2,
#   'rh': 59,
#   'slp': 1018.7,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.4,
#   'timestamp_local': '2022-06-09T02:00:00',
#   'timestamp_utc': '2022-06-09T00:00:00',
#   'ts': 1654732800,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 340,
#   'wind_gust_spd': 15.12,
#   'wind_spd': 3.12},
#  {'app_temp': 16.3,
#   'clouds': 25,
#   'clouds_hi': 98,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-09:03',
#   'dewpt': 10,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 294.8,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 883.4,
#   'rh': 66,
#   'slp': 1019.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 16.3,
#   'timestamp_local': '2022-06-09T05:00:00',
#   'timestamp_utc': '2022-06-09T03:00:00',
#   'ts': 1654743600,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 334,
#   'wind_gust_spd': 8.59,
#   'wind_spd': 2.17},
#  {'app_temp': 17.1,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-09:06',
#   'dewpt': 9.8,
#   'dhi': 55.51,
#   'dni': 537.1,
#   'ghi': 160.1,
#   'ozone': 294.8,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 884,
#   'rh': 62,
#   'slp': 1020,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 160.1,
#   'temp': 17.1,
#   'timestamp_local': '2022-06-09T08:00:00',
#   'timestamp_utc': '2022-06-09T06:00:00',
#   'ts': 1654754400,
#   'uv': 1.6,
#   'vis': 24.128,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 341,
#   'wind_gust_spd': 6.64,
#   'wind_spd': 1.93},
#  {'app_temp': 22.4,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-09:09',
#   'dewpt': 10.3,
#   'dhi': 103.56,
#   'dni': 869.97,
#   'ghi': 718.38,
#   'ozone': 293.5,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 884.6,
#   'rh': 45,
#   'slp': 1019.6,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 718.38,
#   'temp': 22.9,
#   'timestamp_local': '2022-06-09T11:00:00',
#   'timestamp_utc': '2022-06-09T09:00:00',
#   'ts': 1654765200,
#   'uv': 5.5,
#   'vis': 24.128,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 52,
#   'wind_gust_spd': 6.61,
#   'wind_spd': 0.64},
#  {'app_temp': 26.7,
#   'clouds': 0,
#   'clouds_hi': 11,
#   'clouds_low': 1,
#   'clouds_mid': 0,
#   'datetime': '2022-06-09:12',
#   'dewpt': 9.9,
#   'dhi': 117.68,
#   'dni': 938.7,
#   'ghi': 1002.19,
#   'ozone': 295.5,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 884.2,
#   'rh': 34,
#   'slp': 1018.4,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 1002.19,
#   'temp': 27.1,
#   'timestamp_local': '2022-06-09T14:00:00',
#   'timestamp_utc': '2022-06-09T12:00:00',
#   'ts': 1654776000,
#   'uv': 10.3,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NNE',
#   'wind_cdir_full': 'north-northeast',
#   'wind_dir': 18,
#   'wind_gust_spd': 5.18,
#   'wind_spd': 2.04},
#  {'app_temp': 27.8,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 7,
#   'clouds_mid': 14,
#   'datetime': '2022-06-09:15',
#   'dewpt': 10,
#   'dhi': 107.82,
#   'dni': 891.77,
#   'ghi': 796.97,
#   'ozone': 298.8,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 883.7,
#   'rh': 31,
#   'slp': 1017.2,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 796.97,
#   'temp': 28.8,
#   'timestamp_local': '2022-06-09T17:00:00',
#   'timestamp_utc': '2022-06-09T15:00:00',
#   'ts': 1654786800,
#   'uv': 6.6,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NNE',
#   'wind_cdir_full': 'north-northeast',
#   'wind_dir': 20,
#   'wind_gust_spd': 6.7,
#   'wind_spd': 3.03},
#  {'app_temp': 26.5,
#   'clouds': 65,
#   'clouds_hi': 0,
#   'clouds_low': 2,
#   'clouds_mid': 76,
#   'datetime': '2022-06-09:18',
#   'dewpt': 8.1,
#   'dhi': 67.93,
#   'dni': 641.41,
#   'ghi': 255.46,
#   'ozone': 299,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 883.2,
#   'rh': 30,
#   'slp': 1016.7,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 196.409,
#   'temp': 27.2,
#   'timestamp_local': '2022-06-09T20:00:00',
#   'timestamp_utc': '2022-06-09T18:00:00',
#   'ts': 1654797600,
#   'uv': 1,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NNE',
#   'wind_cdir_full': 'north-northeast',
#   'wind_dir': 26,
#   'wind_gust_spd': 7.24,
#   'wind_spd': 3.48},
#  {'app_temp': 20.6,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 5,
#   'datetime': '2022-06-09:21',
#   'dewpt': 5.8,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 300.8,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 884.4,
#   'rh': 36,
#   'slp': 1019.2,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 21.4,
#   'timestamp_local': '2022-06-09T23:00:00',
#   'timestamp_utc': '2022-06-09T21:00:00',
#   'ts': 1654808400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 354,
#   'wind_gust_spd': 8.52,
#   'wind_spd': 2.86},
#  {'app_temp': 17.7,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-10:00',
#   'dewpt': 5.5,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 303.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 884.9,
#   'rh': 42,
#   'slp': 1020.3,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.7,
#   'timestamp_local': '2022-06-10T02:00:00',
#   'timestamp_utc': '2022-06-10T00:00:00',
#   'ts': 1654819200,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#   'wind_cdir': 'NNE',
#   'wind_cdir_full': 'north-northeast',
#   'wind_dir': 20,
#   'wind_gust_spd': 8.95,
#   'wind_spd': 2.48},
#  {'app_temp': 18.1,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-10:03',
#   'dewpt': -2.2,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 305.8,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 884.7,
#   'rh': 25,
#   'slp': 1020.2,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.1,
#   'timestamp_local': '2022-06-10T05:00:00',
#   'timestamp_utc': '2022-06-10T03:00:00',
#   'ts': 1654830000,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#   'wind_cdir': 'NNE',
#   'wind_cdir_full': 'north-northeast',
#   'wind_dir': 14,
#   'wind_gust_spd': 8.87,
#   'wind_spd': 1.87},
#  {'app_temp': 17.5,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-10:06',
#   'dewpt': -3.2,
#   'dhi': 55.54,
#   'dni': 537.28,
#   'ghi': 160.29,
#   'ozone': 310.5,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 884.9,
#   'rh': 22,
#   'slp': 1020.4,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 160.29,
#   'temp': 18.9,
#   'timestamp_local': '2022-06-10T08:00:00',
#   'timestamp_utc': '2022-06-10T06:00:00',
#   'ts': 1654840800,
#   'uv': 1.6,
#   'vis': 24.128,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#   'wind_cdir': 'N',
#   'wind_cdir_full': 'north',
#   'wind_dir': 3,
#   'wind_gust_spd': 5.29,
#   'wind_spd': 1.76},
#  {'app_temp': 25.5,
#   'clouds': 62,
#   'clouds_hi': 5,
#   'clouds_low': 62,
#   'clouds_mid': 28,
#   'datetime': '2022-06-10:09',
#   'dewpt': 5.7,
#   'dhi': 103.54,
#   'dni': 869.8,
#   'ghi': 718.31,
#   'ozone': 311.8,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 912.5,
#   'rh': 27,
#   'slp': 1018,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 578.601,
#   'temp': 26.1,
#   'timestamp_local': '2022-06-10T11:00:00',
#   'timestamp_utc': '2022-06-10T09:00:00',
#   'ts': 1654851600,
#   'uv': 3.1,
#   'vis': 24.128,
#   'weather': {'code': 803, 'description': 'Broken clouds', 'icon': 'c03d'},
#   'wind_cdir': 'ESE',
#   'wind_cdir_full': 'east-southeast',
#   'wind_dir': 107,
#   'wind_gust_spd': 2.5,
#   'wind_spd': 1.95},
#  {'app_temp': 29.1,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-10:12',
#   'dewpt': 9,
#   'dhi': 117.67,
#   'dni': 938.58,
#   'ghi': 1002.4,
#   'ozone': 313.5,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 912,
#   'rh': 26,
#   'slp': 1016.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 1002.4,
#   'temp': 30.7,
#   'timestamp_local': '2022-06-10T14:00:00',
#   'timestamp_utc': '2022-06-10T12:00:00',
#   'ts': 1654862400,
#   'uv': 10.3,
#   'vis': 24.128,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 125,
#   'wind_gust_spd': 2.21,
#   'wind_spd': 2.75},
#  {'app_temp': 30.7,
#   'clouds': 31,
#   'clouds_hi': 0,
#   'clouds_low': 7,
#   'clouds_mid': 31,
#   'datetime': '2022-06-10:15',
#   'dewpt': 9.3,
#   'dhi': 107.85,
#   'dni': 891.85,
#   'ghi': 797.85,
#   'ozone': 312.5,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 910.5,
#   'rh': 24,
#   'slp': 1014.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 784.46,
#   'temp': 32.4,
#   'timestamp_local': '2022-06-10T17:00:00',
#   'timestamp_utc': '2022-06-10T15:00:00',
#   'ts': 1654873200,
#   'uv': 5.2,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 143,
#   'wind_gust_spd': 4.31,
#   'wind_spd': 3.98},
#  {'app_temp': 20.9,
#   'clouds': 2,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 2,
#   'datetime': '2022-06-10:18',
#   'dewpt': 12.9,
#   'dhi': 68.07,
#   'dni': 642.51,
#   'ghi': 256.82,
#   'ozone': 311,
#   'pod': 'd',
#   'pop': 35,
#   'precip': 0.5,
#   'pres': 910.5,
#   'rh': 59,
#   'slp': 1016,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 247.775,
#   'temp': 21.2,
#   'timestamp_local': '2022-06-10T20:00:00',
#   'timestamp_utc': '2022-06-10T18:00:00',
#   'ts': 1654884000,
#   'uv': 1.8,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02d'},
#   'wind_cdir': 'N',
#   'wind_cdir_full': 'north',
#   'wind_dir': 5,
#   'wind_gust_spd': 7.41,
#   'wind_spd': 5.29},
#  {'app_temp': 18.5,
#   'clouds': 4,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 4,
#   'datetime': '2022-06-10:21',
#   'dewpt': 12.6,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 310,
#   'pod': 'n',
#   'pop': 20,
#   'precip': 0.25,
#   'pres': 913,
#   'rh': 67,
#   'slp': 1019,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.8,
#   'timestamp_local': '2022-06-10T23:00:00',
#   'timestamp_utc': '2022-06-10T21:00:00',
#   'ts': 1654894800,
#   'uv': 0,
#   'vis': 20.016,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02n'},
#   'wind_cdir': 'NNE',
#   'wind_cdir_full': 'north-northeast',
#   'wind_dir': 28,
#   'wind_gust_spd': 3.6,
#   'wind_spd': 3.09},
#  {'app_temp': 18.6,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-11:00',
#   'dewpt': 12.4,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 307.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 912.5,
#   'rh': 66,
#   'slp': 1018.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.9,
#   'timestamp_local': '2022-06-11T02:00:00',
#   'timestamp_utc': '2022-06-11T00:00:00',
#   'ts': 1654905600,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#   'wind_cdir': 'NNE',
#   'wind_cdir_full': 'north-northeast',
#   'wind_dir': 26,
#   'wind_gust_spd': 2,
#   'wind_spd': 2.12},
#  {'app_temp': 17.9,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-11:03',
#   'dewpt': 11.7,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 304.8,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 912.5,
#   'rh': 65,
#   'slp': 1018.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.3,
#   'timestamp_local': '2022-06-11T05:00:00',
#   'timestamp_utc': '2022-06-11T03:00:00',
#   'ts': 1654916400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 35,
#   'wind_gust_spd': 1.4,
#   'wind_spd': 1.46},
#  {'app_temp': 19.9,
#   'clouds': 5,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 5,
#   'datetime': '2022-06-11:06',
#   'dewpt': 12.5,
#   'dhi': 55.54,
#   'dni': 537.36,
#   'ghi': 160.39,
#   'ozone': 305.3,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 913,
#   'rh': 61,
#   'slp': 1019,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 154.834,
#   'temp': 20.3,
#   'timestamp_local': '2022-06-11T08:00:00',
#   'timestamp_utc': '2022-06-11T06:00:00',
#   'ts': 1654927200,
#   'uv': 1.6,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02d'},
#   'wind_cdir': 'ENE',
#   'wind_cdir_full': 'east-northeast',
#   'wind_dir': 62,
#   'wind_gust_spd': 1.51,
#   'wind_spd': 1.38},
#  {'app_temp': 26.4,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-11:09',
#   'dewpt': 11.9,
#   'dhi': 103.52,
#   'dni': 869.62,
#   'ghi': 718.18,
#   'ozone': 305.3,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 913.5,
#   'rh': 40,
#   'slp': 1018.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 694.7,
#   'temp': 26.6,
#   'timestamp_local': '2022-06-11T11:00:00',
#   'timestamp_utc': '2022-06-11T09:00:00',
#   'ts': 1654938000,
#   'uv': 5.5,
#   'vis': 24.128,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#   'wind_cdir': 'ESE',
#   'wind_cdir_full': 'east-southeast',
#   'wind_dir': 113,
#   'wind_gust_spd': 2.91,
#   'wind_spd': 2.72},
#  {'app_temp': 29.7,
#   'clouds': 1,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 1,
#   'datetime': '2022-06-11:12',
#   'dewpt': 10.9,
#   'dhi': 117.66,
#   'dni': 938.45,
#   'ghi': 1002.57,
#   'ozone': 303.8,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 913,
#   'rh': 29,
#   'slp': 1017.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 971.91,
#   'temp': 31.1,
#   'timestamp_local': '2022-06-11T14:00:00',
#   'timestamp_utc': '2022-06-11T12:00:00',
#   'ts': 1654948800,
#   'uv': 10.3,
#   'vis': 24.128,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 126,
#   'wind_gust_spd': 3.42,
#   'wind_spd': 3.64},
#  {'app_temp': 31.6,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-11:15',
#   'dewpt': 6.9,
#   'dhi': 107.88,
#   'dni': 891.92,
#   'ghi': 798.69,
#   'ozone': 303.3,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 911.5,
#   'rh': 19,
#   'slp': 1015.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 798.69,
#   'temp': 33.7,
#   'timestamp_local': '2022-06-11T17:00:00',
#   'timestamp_utc': '2022-06-11T15:00:00',
#   'ts': 1654959600,
#   'uv': 6.6,
#   'vis': 24.128,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 128,
#   'wind_gust_spd': 4.11,
#   'wind_spd': 3.29},
#  {'app_temp': 30.9,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-11:18',
#   'dewpt': 5.6,
#   'dhi': 68.21,
#   'dni': 643.56,
#   'ghi': 258.12,
#   'ozone': 305,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 910.5,
#   'rh': 18,
#   'slp': 1014,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 258.12,
#   'temp': 33.1,
#   'timestamp_local': '2022-06-11T20:00:00',
#   'timestamp_utc': '2022-06-11T18:00:00',
#   'ts': 1654970400,
#   'uv': 1.8,
#   'vis': 24.128,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01d'},
#   'wind_cdir': 'S',
#   'wind_cdir_full': 'south',
#   'wind_dir': 172,
#   'wind_gust_spd': 5.1,
#   'wind_spd': 3.15},
#  {'app_temp': 21.7,
#   'clouds': 4,
#   'clouds_hi': 4,
#   'clouds_low': 0,
#   'clouds_mid': 4,
#   'datetime': '2022-06-11:21',
#   'dewpt': 10.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 304,
#   'pod': 'n',
#   'pop': 20,
#   'precip': 0.270833,
#   'pres': 913,
#   'rh': 46,
#   'slp': 1018.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 22.2,
#   'timestamp_local': '2022-06-11T23:00:00',
#   'timestamp_utc': '2022-06-11T21:00:00',
#   'ts': 1654981200,
#   'uv': 0,
#   'vis': 9.6,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02n'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 45,
#   'wind_gust_spd': 1.82,
#   'wind_spd': 2.29},
#  {'app_temp': 19.4,
#   'clouds': 1,
#   'clouds_hi': 5,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-12:00',
#   'dewpt': 12.5,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 304.3,
#   'pod': 'n',
#   'pop': 25,
#   'precip': 0.333333,
#   'pres': 914,
#   'rh': 63,
#   'slp': 1020,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 19.8,
#   'timestamp_local': '2022-06-12T02:00:00',
#   'timestamp_utc': '2022-06-12T00:00:00',
#   'ts': 1654992000,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02n'},
#   'wind_cdir': 'ENE',
#   'wind_cdir_full': 'east-northeast',
#   'wind_dir': 65,
#   'wind_gust_spd': 3.34,
#   'wind_spd': 2.82},
#  {'app_temp': 18.4,
#   'clouds': 25,
#   'clouds_hi': 100,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-12:03',
#   'dewpt': 11.4,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 303.8,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 913.5,
#   'rh': 62,
#   'slp': 1019.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.8,
#   'timestamp_local': '2022-06-12T05:00:00',
#   'timestamp_utc': '2022-06-12T03:00:00',
#   'ts': 1655002800,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02n'},
#   'wind_cdir': 'ENE',
#   'wind_cdir_full': 'east-northeast',
#   'wind_dir': 76,
#   'wind_gust_spd': 2.02,
#   'wind_spd': 1.89},
#  {'app_temp': 19,
#   'clouds': 19,
#   'clouds_hi': 77,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2022-06-12:06',
#   'dewpt': 11.7,
#   'dhi': 55.54,
#   'dni': 537.32,
#   'ghi': 160.42,
#   'ozone': 305.3,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 914.5,
#   'rh': 61,
#   'slp': 1020.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 154.576,
#   'temp': 19.4,
#   'timestamp_local': '2022-06-12T08:00:00',
#   'timestamp_utc': '2022-06-12T06:00:00',
#   'ts': 1655013600,
#   'uv': 1.4,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 41,
#   'wind_gust_spd': 3.31,
#   'wind_spd': 2.49}]

# %%
len(results['data'])
# Out:
# 40

# %%
#5 days every 3hourly
(24 * 5) /3
# Out:
# 40.0
